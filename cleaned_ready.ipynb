# %%
from clean import *

# %%
df = generate_mta_data(num_weeks=2)
df
# Out:
#                    level_0  level_1   C/A  UNIT       SCP    STATION LINENAME  \
# 0            1 AV 00-00-00    32826  H007  R248  00-00-00       1 AV        L
# 1            1 AV 00-00-00    32827  H007  R248  00-00-00       1 AV        L
# 2            1 AV 00-00-00    32828  H007  R248  00-00-00       1 AV        L
# 3            1 AV 00-00-00    32829  H007  R248  00-00-00       1 AV        L
# 4            1 AV 00-00-00    32830  H007  R248  00-00-00       1 AV        L
# ...                    ...      ...   ...   ...       ...        ...      ...
# 212294  ZEREGA AV 00-05-01   186913  R419  R326  00-05-01  ZEREGA AV        6
# 212295  ZEREGA AV 00-05-01   186914  R419  R326  00-05-01  ZEREGA AV        6
# 212296  ZEREGA AV 00-05-01   186915  R419  R326  00-05-01  ZEREGA AV        6
# 212297  ZEREGA AV 00-05-01   186916  R419  R326  00-05-01  ZEREGA AV        6
# 212298  ZEREGA AV 00-05-01   186917  R419  R326  00-05-01  ZEREGA AV        6
#
# ...
