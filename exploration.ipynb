# %%
import pandas as pd
import os

pd.set_option("display.max_columns", 500)
df = pd.read_csv('mta/turnstile_210102.txt')
df
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  12/26/2020
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  12/26/2020
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  12/26/2020
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  12/26/2020
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  12/26/2020
# ...       ...   ...       ...            ...      ...      ...         ...
# 210428  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/01/2021
# 210429  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/01/2021
# 210430  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/01/2021
# 210431  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/01/2021
# 210432  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  01/01/2021
#
#             TIME     DESC  ENTRIES  \
# 0       03:00:00  REGULAR  7508509
# 1       07:00:00  REGULAR  7508511
# 2       11:00:00  REGULAR  7508531
# 3       15:00:00  REGULAR  7508610
# 4       19:00:00  REGULAR  7508767
# ...          ...      ...      ...
# 210428  04:00:00  REGULAR     5554
# 210429  08:00:00  REGULAR     5554
# 210430  12:00:00  REGULAR     5554
# 210431  16:00:00  REGULAR     5554
# 210432  20:00:00  REGULAR     5554
#
#         EXITS
# 0                                                 2557569
# 1                                                 2557581
# 2                                                 2557636
# 3                                                 2557667
# 4                                                 2557689
# ...                                                   ...
# 210428                                                541
# 210429                                                541
# 210430                                                541
# 210431                                                541
# 210432                                                541
#
# [210433 rows x 11 columns]

# %%
def mta_to_df():
    filenames = os.listdir('mta')
    data = pd.DataFrame()

    for file in filenames:
        df = pd.read_csv('mta/' + file)
        data = pd.concat([data, df])
    return data

# %%
get_files()
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  11/14/2020
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  11/14/2020
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  11/14/2020
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  11/14/2020
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  11/14/2020
# ...       ...   ...       ...            ...      ...      ...         ...
# 213100  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  11/06/2020
# 213101  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  11/06/2020
# 213102  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  11/06/2020
# 213103  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  11/06/2020
# 213104  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  11/06/2020
#
#             TIME     DESC    ENTRIES  \
# 0       03:00:00  REGULAR  7488490.0
# 1       07:00:00  REGULAR  7488497.0
# 2       11:00:00  REGULAR  7488527.0
# 3       15:00:00  REGULAR  7488630.0
# 4       19:00:00  REGULAR  7488805.0
# ...          ...      ...        ...
# 213100  04:00:00  REGULAR     5554.0
# 213101  08:00:00  REGULAR     5554.0
# 213102  12:00:00  REGULAR     5554.0
# 213103  16:00:00  REGULAR     5554.0
# 213104  20:00:00  REGULAR     5554.0
#
#         EXITS                                                                 \
# 0                                               2548950.0
# 1                                               2548957.0
# 2                                               2549007.0
# 3                                               2549046.0
# 4                                               2549080.0
# ...                                                   ...
# 213100                                              541.0
# 213101                                              541.0
# 213102                                              541.0
# 213103                                              541.0
# 213104                                              541.0
#
#        Unnamed: 0
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 213100        NaN
# 213101        NaN
# 213102        NaN
# 213103        NaN
# 213104        NaN
#
# [2107737 rows x 12 columns]
