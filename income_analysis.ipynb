# %%
import pandas as pd
import numpy as np

import json

# %%
from clean2 import *
# from clean2 import data_wrangling

# %%
# get data using funcs from clean2.py
df = data_wrangling()

# %%
df.head(100000).tail(99985)
# Out:
#                  DATE_TIME    C/A  UNIT       SCP        STATION LINENAME  \
# 192862 2016-09-14 09:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 192861 2016-09-14 05:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 192860 2016-09-14 01:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 192859 2016-09-13 21:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 192858 2016-09-13 17:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# ...                    ...    ...   ...       ...            ...      ...
# 161382 2016-09-07 16:00:00   R306  R207  00-00-03         135 ST       23
# 161381 2016-09-07 12:00:00   R306  R207  00-00-03         135 ST       23
# 161380 2016-09-07 08:00:00   R306  R207  00-00-03         135 ST       23
# 161379 2016-09-07 04:00:00   R306  R207  00-00-03         135 ST       23
# 161378 2016-09-07 00:00:00   R306  R207  00-00-03         135 ST       23
#
#        DIVISION        DATE      TIME  ENTRIES    EXITS AMPM   DAY_NAME
# ...

# %%
mta_station_info = pd.read_csv("http://web.mta.info/developers/data/nyct/subway/Stations.csv")
mta_station_info.rename(columns={'GTFS Latitude': 'Lat', 'GTFS Longitude': 'Lon', 'Stop Name': 'Station'}, inplace=True)
mta_station_info
# Out:
#      Station ID  Complex ID GTFS Stop ID Division           Line  \
# 0             1           1          R01      BMT        Astoria
# 1             2           2          R03      BMT        Astoria
# 2             3           3          R04      BMT        Astoria
# 3             4           4          R05      BMT        Astoria
# 4             5           5          R06      BMT        Astoria
# ..          ...         ...          ...      ...            ...
# 491         517         517          S15      SIR  Staten Island
# 492         518         518          S14      SIR  Staten Island
# 493         519         519          S13      SIR  Staten Island
# 494         522         522          S09      SIR  Staten Island
# 495         523         523          S11      SIR  Staten Island
#
#                   Station Borough Daytime Routes   Structure        Lat  \
# 0    Astoria-Ditmars Blvd       Q            N W    Elevated  40.775036
# ...

# %% [markdown]
# Data source for income by zip code: (US Census) https://catalog.data.gov/dataset/zip-code-data

# %%
us_zips = pd.read_csv("18zpallagi.csv")
us_zips.rename(columns={'A00100':'adj_gross_inc'}, inplace=True)
# us_zips_agi = us_zips[['zipcode','adj_gross_inc']].groupby('zipcode').agg(sum)

us_zips_agi
# Out:
#          adj_gross_inc
# zipcode
# 0         1.168118e+10
# 1001      5.467750e+05
# 1002      8.848890e+05
# 1005      1.492950e+05
# 1007      6.203770e+05
# ...                ...
# 99827     8.882500e+04
# 99833     1.144710e+05
# 99835     3.163940e+05
# 99901     4.377110e+05
# 99999     2.136667e+08
#
# [27558 rows x 1 columns]

# %% [markdown]
# Now that we have all USA zip codes, we need to get a list of only those in NYC. nycbynatives.com offers a complete list of these zip codes along with the corresponding neighborhoods. I copy/pasted them into 'ny_zips.csv'
#
# source: https://www.nycbynatives.com/nyc_info/new_york_city_zip_codes.php

# %%
nyc_zips = pd.read_csv("ny_zips.csv")
#nyc_zips.dropna(axis=1, how='all', inplace=True)

nyc_agi_by_zip = nyc_zips.join(us_zips_agi, how='inner', on='zipcode')

nyc_agi_by_zip
# Out:
#      zipcode       area  adj_gross_inc
# 0      10001  Manhattan      2906435.0
# 1      10002  Manhattan      2718913.0
# 2      10003  Manhattan      8191737.0
# 3      10004  Manhattan       944925.0
# 4      10005  Manhattan      2603668.0
# ..       ...        ...            ...
# 235    11691     Queens      1033194.0
# 236    11692     Queens       393888.0
# 237    11693     Queens       319792.0
# 238    11694     Queens       850523.0
# 239    11697     Queens       253659.0
#
# [176 rows x 3 columns]

# %% [markdown]
# ## Latitude/Longitude to Zip Code

# %%
mta_station_info = pd.read_csv("http://web.mta.info/developers/data/nyct/subway/Stations.csv")
mta_station_info.rename(columns={'GTFS Latitude': 'Lat', 'GTFS Longitude': 'Lon'}, inplace=True)

# %%
coords = mta_station_info[['Lat', 'Lon']]

# %%
# convert lat/lon to zip codes (NOT WORKING)
# import geopy

# from arcgis.geocoding import reverse_geocode
# from arcgis.geometry import Geometry
# from arcgis.gis import GIS
# import pandas as pd

# gis = GIS("http://www.arcgis.com", "***", "***")

# def get_zip(df, lon_field, lat_field):
#     location = reverse_geocode((Geometry({"x":float(df[lon_field]), "y":float(df[lat_field]), "spatialReference":{"wkid": 4326}})))
#     return location['address']['Postal']

# df = pd.DataFrame({
#     'Lat': [29.39291, 29.39923, 29.40147, 29.38752, 29.39291, 29.39537, 29.39343, 29.39291, 29.39556],
#     'Lon': [-98.50925, -98.51256, -98.51123, -98.52372, -98.50925, -98.50402, -98.49707, -98.50925, -98.53148]
# })

# zipcodes = mta_station_info.apply(get_zip, axis=1, lat_field='Lat', lon_field='Lon')

# %%
mta_station_names = list(df.STATION.unique())
mta_station_names
# Out:
# ['RIT-ROOSEVELT',
#  'RIT-MANHATTAN',
#  'TOMPKINSVILLE',
#  'ST. GEORGE',
#  'EASTCHSTER/DYRE',
#  'BAYCHESTER AV',
#  'GUN HILL RD',
#  'PELHAM PKWY',
#  'MORRIS PARK',
#  'FLATBUSH AV-B.C',
#  'NEWKIRK AV',
#  'BEVERLY RD',
#  'CHURCH AV',
#  'WINTHROP ST',
#  'STERLING ST',
#  'PRESIDENT ST',
#  'NEW LOTS AV',
#  'VAN SICLEN AV',
#  'PENNSYLVANIA AV',
#  'JUNIUS ST',
#  'ROCKAWAY AV',
#  'SARATOGA AV',
#  'SUTTER AV-RUTLD',
#  'CROWN HTS-UTICA',
#  'KINGSTON AV',
#  'NOSTRAND AV',
#  'FRANKLIN AV',
#  'EASTN PKWY-MUSM',
#  'GRAND ARMY PLAZ',
#  'BERGEN ST',
#  'ATL AV-BARCLAY',
#  'NEVINS ST',
#  'HOYT ST',
#  'BOROUGH HALL',
#  'CLARK ST',
#  '34 ST-HUDSON YD',
#  'FLUSHING-MAIN',
#  'METS-WILLETS PT',
#  '111 ST',
#  '103 ST-CORONA',
#  'JUNCTION BLVD',
#  '90 ST-ELMHURST',
#  '82 ST-JACKSON H',
#  '74 ST-BROADWAY',
#  '69 ST',
#  '61 ST WOODSIDE',
#  '52 ST',
#  '46 ST BLISS ST',
#  '40 ST LOWERY ST',
#  '33 ST-RAWSON ST',
#  'ASTORIA DITMARS',
#  'ASTORIA BLVD',
#  '30 AV',
# ...

# %%
geolocator = geopy.Nominatim(user_agent='mta-da')

# for station in mta_station_names:
#     address = station + ' Station New York City, NY'
    
#     location = geolocator.reverse((lat, lon)
# Out:
#   File "<ipython-input-12-54aba480ece8>", line 7
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
import geopy

def get_zip(df, geolocator, lat_field, lon_field):
    location = geolocator.reverse((df[lat_field], df[lon_field]))
    return location.raw['address']['postcode']


geolocator = geopy.Nominatim(user_agent='mta-da')

geo_df = pd.DataFrame({
    'Lat': list(mta_station_info.Lat.round(6)),
    'Lon': list(mta_station_info.Lon.round(6))
})
# zipcodes = mta_station_info.apply(get_zip, axis=1, geolocator=geolocator, lat_field='Lat', lon_field='Lon')

# %%
import googlemaps
gmaps = googlemaps.Client(key='AIzaSyB7VjMRZtf7N8d_kZZhHJSzpkEJ3M8hPrA')
# Geocoding an address
geocode_result = gmaps.geocode('TIMES SQ-42 ST')
lat = geocode_result[0]["geometry"]["location"]["lat"]
lon = geocode_result[0]["geometry"]["location"]["lng"]
geocode_result
# Out:
# [{'address_components': [{'long_name': 'Times Sq - 42 St',
#     'short_name': 'Times Sq - 42 St',
#     'types': ['establishment', 'point_of_interest', 'transit_station']},
#    {'long_name': 'Manhattan',
#     'short_name': 'Manhattan',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'New York',
#     'short_name': 'New York',
#     'types': ['locality', 'political']},
#    {'long_name': 'New York County',
#     'short_name': 'New York County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'New York',
#     'short_name': 'NY',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Times Sq - 42 St, New York, NY, USA',
#   'geometry': {'location': {'lat': 40.7552574, 'lng': -73.986933},
#    'location_type': 'GEOMETRIC_CENTER',
# ...

# %%
def get_zipcode(address):
    """ Adds a zipcode column to the df.
    
        To be used with the df.apply() function
        
        Parameters: address (string) 
        
        Returns: zipcode (string)
        
    """
    # get address that we will feed into Google maps 
    gmaps_full_address = address + ' Subway Station New York City, NY' 
    gmaps = googlemaps.Client(key='AIzaSyB7VjMRZtf7N8d_kZZhHJSzpkEJ3M8hPrA')
    # Geocoding an address
    geocode_result = gmaps.geocode(gmaps_full_address)
    zipcode = geocode_result[0]['address_components'][6]['long_name']
    return zipcode

# %%
gmaps = googlemaps.Client(key='AIzaSyB7VjMRZtf7N8d_kZZhHJSzpkEJ3M8hPrA')
# Geocoding an address
geocode_result = gmaps.geocode('South St, Whitehall St, New York')
zipcode = geocode_result[0]['address_components'][6]['long_name']

json.dumps(zipcode)
# Out:
# '"10004"'

# %%
gmaps = googlemaps.Client(key='AIzaSyB7VjMRZtf7N8d_kZZhHJSzpkEJ3M8hPrA')

station_zips = {}

for station in mta_station_names:
    address = station + ' Station New York City, NY'
    geocode_result = gmaps.geocode(address)
    print(station)
    try:
        zipcode = geocode_result[0]['address_components'][6]['long_name']
        if len(zipcode) == 5:
            station_zips[station] = zipcode
    except:
        continue
# Out:
# RIT-ROOSEVELT
# RIT-MANHATTAN
# TOMPKINSVILLE
# ST. GEORGE
# EASTCHSTER/DYRE
# BAYCHESTER AV
# GUN HILL RD
# PELHAM PKWY
# MORRIS PARK
# FLATBUSH AV-B.C
# NEWKIRK AV
# BEVERLY RD
# CHURCH AV
# WINTHROP ST
# STERLING ST
# PRESIDENT ST
# NEW LOTS AV
# VAN SICLEN AV
# PENNSYLVANIA AV
# JUNIUS ST
# ROCKAWAY AV
# SARATOGA AV
# SUTTER AV-RUTLD
# CROWN HTS-UTICA
# KINGSTON AV
# NOSTRAND AV
# FRANKLIN AV
# EASTN PKWY-MUSM
# GRAND ARMY PLAZ
# BERGEN ST
# ATL AV-BARCLAY
# NEVINS ST
# HOYT ST
# BOROUGH HALL
# CLARK ST
# 34 ST-HUDSON YD
# FLUSHING-MAIN
# METS-WILLETS PT
# 111 ST
# 103 ST-CORONA
# JUNCTION BLVD
# 90 ST-ELMHURST
# 82 ST-JACKSON H
# 74 ST-BROADWAY
# 69 ST
# 61 ST WOODSIDE
# 52 ST
# 46 ST BLISS ST
# 40 ST LOWERY ST
# 33 ST-RAWSON ST
# ASTORIA DITMARS
# ASTORIA BLVD
# 30 AV
# BROADWAY
# 36 AV
# 39 AV
# QUEENSBORO PLZ
# COURT SQ
# HUNTERS PT AV
# VERNON-JACKSON
# 5 AVE
# PELHAM BAY PARK
# BUHRE AV
# MIDDLETOWN RD
# WESTCHESTER SQ
# ZEREGA AV
# CASTLE HILL AV
# PARKCHESTER
# ...

# %%
len(mta_station_names)
# Out:
# 374

# %%
station_zips
# Out:
# {'RIT-ROOSEVELT': '10065',
#  'TOMPKINSVILLE': '10304',
#  'EASTCHSTER/DYRE': '10466',
#  'BAYCHESTER AV': '10469',
#  'GUN HILL RD': '10467',
#  'MORRIS PARK': '10462',
#  'BEVERLY RD': '11226',
#  'CHURCH AV': '11226',
#  'WINTHROP ST': '11225',
#  'STERLING ST': '11225',
#  'PRESIDENT ST': '11225',
#  'NEW LOTS AV': '11207',
#  'VAN SICLEN AV': '11207',
#  'PENNSYLVANIA AV': '11207',
#  'JUNIUS ST': '11212',
#  'ROCKAWAY AV': '11224',
#  'SARATOGA AV': '11212',
#  'SUTTER AV-RUTLD': '11212',
#  'CROWN HTS-UTICA': '11213',
#  'KINGSTON AV': '11213',
#  'NOSTRAND AV': '11225',
#  'FRANKLIN AV': '10013',
#  'GRAND ARMY PLAZ': '11238',
#  'BERGEN ST': '11201',
#  'NEVINS ST': '11217',
#  'HOYT ST': '11201',
#  'CLARK ST': '11201',
#  'FLUSHING-MAIN': '11354',
#  '111 ST': '11418',
#  'JUNCTION BLVD': '11368',
#  '90 ST-ELMHURST': '11372',
#  '69 ST': '11377',
#  '61 ST WOODSIDE': '11377',
#  '52 ST': '11377',
#  '46 ST BLISS ST': '11104',
#  '40 ST LOWERY ST': '11104',
# ...

# %%
# import json
# import re

# gmaps = googlemaps.Client(key='AIzaSyB7VjMRZtf7N8d_kZZhHJSzpkEJ3M8hPrA')
# # Geocoding an address
# geocode_result = gmaps.geocode('South St, Whitehall St, New York')
# zipcode = geocode_result
# dicts = json.dumps(zipcode[0])

# regex = r".*address_comp"
# result = re.search(dicts, regex)
# result is None

# %%
import requests

api_key = 'AIzaSyB7VjMRZtf7N8d_kZZhHJSzpkEJ3M8hPrA'

station = 'BAYCHESTER AV'
address = station + ' Station New York City, NY' 

params = {
    'key': api_key,
    'address': address
}

base_url = 'https://maps.googleapis.com/maps/api/geocode/json'
response = requests.get(base_url, params=params).json()
response['results'][0]['location']

# %%
# try by passing in lat/lon
mta_station_info

# %%
import geopy
import pandas as pd


def get_zip(df, geolocator, lat_field, lon_field):
    location = geolocator.reverse((df[lat_field], df[lon_field]))
    return location.raw['address']['postcode']


geolocator = geopy.Nominatim(user_agent='mta-da')

geo_df = pd.DataFrame({
    'Lat': list(mta_station_info.Lat.round(6)),
    'Lon': list(mta_station_info.Lon.round(6))
})
zipcodes = geo_df.apply(get_zip, axis=1, geolocator=geolocator, lat_field='Lat', lon_field='Lon')

# %%
stations

# %%
list(mta_station_info.Lat.round(6))

# %%
stations = list(df.STATION.unique)

# %%
df
# Out:
#                  DATE_TIME    C/A  UNIT       SCP        STATION LINENAME  \
# 192877 2016-09-16 21:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 192876 2016-09-16 17:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 192875 2016-09-16 13:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 192874 2016-09-16 09:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 192873 2016-09-16 05:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# ...                    ...    ...   ...       ...            ...      ...
# 4      2016-08-27 16:00:00   A002  R051  02-00-00          59 ST   NQR456
# 3      2016-08-27 12:00:00   A002  R051  02-00-00          59 ST   NQR456
# 2      2016-08-27 08:00:00   A002  R051  02-00-00          59 ST   NQR456
# 1      2016-08-27 04:00:00   A002  R051  02-00-00          59 ST   NQR456
# 0      2016-08-27 00:00:00   A002  R051  02-00-00          59 ST   NQR456
#
#        DIVISION        DATE      TIME  ENTRIES    EXITS AMPM  DAY_NAME
# ...
