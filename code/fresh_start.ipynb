# %% [markdown]
# # Instructions for using clean2.py

# %% [markdown]
# ``clean2.py`` essentially contains one function: ``data_wrangling()``. This function takes a list of week_numbers (optional) which determine the timeframe of data pulled from MTA turnstile data.
#
# We get two dataframes using the command below:
# - ``df_turnstiles``: contains all turnstile data
# - ``df_ampm``: contains the same data, this time broken down by am/pm
#     - 2 entries for each station, for each day (one for AM, one for PM)
#
# **NOTE 1**: This part requires a key for Google's geocode API. The below key will be deactivated before it's made public. Get one yourself (it's free\*, fast and easy) [here](https://developers.google.com/maps/documentation/geocoding/start). \*okay, it's free if you're just using it here. I think it would charge you if you ran the below cell 100s of times or use it for other applications.
#
# Then, pass the api key (as a string) as the ``geocode_api_key`` parameter of the ``data_wrangling`` function used in the next cell.
#
# **NOTE 2**: The following cell takes 4-7 minutes to run. By default, the program takes 8 weeks of MTA turnstile data. You can change the ``week_nums`` parameter of ``data_wrangling`` to a smaller number of weeks. This will only save you 1-2 minutes, since a majority of the time is spent on the geocode API (see [wtwy_data_merge.ipynb](https://github.com/edubu2/metis-project1/blob/main/code/wtwy_data_merge.ipynb) for details).

# %%
from clean2 import data_wrangling

# must replace geocode_api_key's empty string with a valid key
df_turnstiles, df_ampm = data_wrangling(geocode_api_key='AIzaSyCGo0NcvTdM9fgFx7y8BzShf5OJLHH562U')

# %% [markdown]
# **Let's take a look at ``df_turnstiles``**:

# %%
df_turnstiles.sample(10)
# Out:
#                  DATE_TIME    C/A  UNIT       SCP          STATION  LINENAME  \
# 151985 2019-11-25 12:00:00   R208  R014  03-00-01        FULTON ST  2345ACJZ
# 16077  2019-11-12 23:00:00   B021  R228  00-00-00         AVENUE J        BQ
# 159911 2019-11-13 08:00:00   R240  R047  00-03-07  GRD CNTRL-42 ST     4567S
# 16011  2019-11-29 07:00:00   B020  R263  00-06-00         AVENUE H        BQ
# 166613 2019-11-30 11:00:00   R253  R181  00-00-01           110 ST         6
# 67192  2019-11-08 04:00:00   N120  R153  00-00-01         UTICA AV        AC
# 200779 2019-11-10 04:00:00   R639  R109  00-00-03        CHURCH AV        25
# 79028  2019-12-13 03:00:00  N305A  R016  00-05-01  LEXINGTON AV/53       EM6
# 10537  2019-11-02 00:00:00   A055  R227  00-00-03        RECTOR ST       NRW
# 181196 2019-12-13 00:00:00   R422  R428  00-05-00         BUHRE AV         6
#
#        DIVISION        DATE      TIME   ENTRIES    EXITS AMPM   DAY_NAME  \
# 151985      IRT  11/25/2019  12:00:00     27691    64950   PM     Monday
# 16077       BMT  11/12/2019  23:00:00   9390032  7846874   PM    Tuesday
# 159911      IRT  11/13/2019  08:00:00   8827535  2478268   AM  Wednesday
# 16011       BMT  11/29/2019  07:00:00     29249   222447   AM     Friday
# 166613      IRT  11/30/2019  11:00:00   5599505  8824400   AM   Saturday
# 67192       IND  11/08/2019  04:00:00   5859148  6875235   AM     Friday
# 200779      IRT  11/10/2019  04:00:00  22774690  2410333   AM     Sunday
# 79028       IND  12/13/2019  03:00:00         6     1864   AM     Friday
# 10537       BMT  11/02/2019  00:00:00   3274435  1085644   AM   Saturday
# 181196      IRT  12/13/2019  00:00:00       517        0   AM     Friday
#
#        ZIPCODE  ZIPCODE_AGI
# 151985     NaN          NaN
# 16077    11230    2773769.0
# 159911     NaN          NaN
# 16011    11230    2773769.0
# 166613   10029    2022052.0
# 67192    11213    1378248.0
# 200779   11226    2466184.0
# 79028      NaN          NaN
# 10537    10006     577145.0
# 181196   10461    1346454.0

# %% [markdown]
# **And now ``df_ampm``**:

# %%
df_ampm.head(35)
# Out:
#      C/A  UNIT STATION        DATE AMPM   DAY_NAME   ENTRIES    EXITS  \
# 1   A002  R051   59 ST  11/02/2019   PM   Saturday  11714240  8552046
# 2   A002  R051   59 ST  11/03/2019   AM     Sunday  11714756  8552455
# 3   A002  R051   59 ST  11/03/2019   PM     Sunday  11715887  8553273
# 4   A002  R051   59 ST  11/04/2019   AM     Monday  11716360  8554098
# 5   A002  R051   59 ST  11/04/2019   PM     Monday  11717806  8554809
# 6   A002  R051   59 ST  11/05/2019   AM    Tuesday  11718319  8555630
# 7   A002  R051   59 ST  11/05/2019   PM    Tuesday  11719843  8556402
# 8   A002  R051   59 ST  11/06/2019   AM  Wednesday  11720383  8557257
# 9   A002  R051   59 ST  11/06/2019   PM  Wednesday  11721866  8558037
# 10  A002  R051   59 ST  11/07/2019   AM   Thursday  11722410  8558944
# 11  A002  R051   59 ST  11/07/2019   PM   Thursday  11723898  8559685
# 12  A002  R051   59 ST  11/08/2019   AM     Friday  11724401  8560470
# 13  A002  R051   59 ST  11/08/2019   PM     Friday  11725887  8561242
# 14  A002  R051   59 ST  11/09/2019   AM   Saturday  11726236  8561655
# 15  A002  R051   59 ST  11/09/2019   PM   Saturday  11727263  8562522
# 16  A002  R051   59 ST  11/10/2019   AM     Sunday  11727557  8562788
# 17  A002  R051   59 ST  11/10/2019   PM     Sunday  11728448  8563508
# 18  A002  R051   59 ST  11/11/2019   AM     Monday  11728873  8564246
# 19  A002  R051   59 ST  11/11/2019   PM     Monday  11730220  8565004
# 20  A002  R051   59 ST  11/12/2019   AM    Tuesday  11730762  8565835
# 21  A002  R051   59 ST  11/12/2019   PM    Tuesday  11732197  8566527
# 22  A002  R051   59 ST  11/13/2019   AM  Wednesday  11732724  8567361
# 23  A002  R051   59 ST  11/13/2019   PM  Wednesday  11734161  8568093
# 24  A002  R051   59 ST  11/14/2019   AM   Thursday  11734721  8568921
# 25  A002  R051   59 ST  11/14/2019   PM   Thursday  11736171  8569637
# 26  A002  R051   59 ST  11/15/2019   AM     Friday  11736679  8570440
# 27  A002  R051   59 ST  11/15/2019   PM     Friday  11738107  8571178
# 28  A002  R051   59 ST  11/16/2019   AM   Saturday  11738409  8571549
# 29  A002  R051   59 ST  11/16/2019   PM   Saturday  11739463  8572344
# 30  A002  R051   59 ST  11/17/2019   AM     Sunday  11739708  8572613
# 31  A002  R051   59 ST  11/17/2019   PM     Sunday  11740497  8573200
# 32  A002  R051   59 ST  11/18/2019   AM     Monday  11740979  8574062
# 33  A002  R051   59 ST  11/18/2019   PM     Monday  11742385  8574785
# 34  A002  R051   59 ST  11/19/2019   AM    Tuesday  11742919  8575713
# 35  A002  R051   59 ST  11/19/2019   PM    Tuesday  11744418  8576615
#
#      PREV_DATE  PREV_ENTRIES  PREV_EXITS  TMP_ENTRIES  TMP_EXITS  TRAFFIC  \
# 1   11/02/2019    11713245.0   8551395.0        995.0      651.0   1646.0
# 2   11/02/2019    11714240.0   8552046.0        516.0      409.0    925.0
# 3   11/03/2019    11714756.0   8552455.0       1131.0      818.0   1949.0
# 4   11/03/2019    11715887.0   8553273.0        473.0      825.0   1298.0
# 5   11/04/2019    11716360.0   8554098.0       1446.0      711.0   2157.0
# 6   11/04/2019    11717806.0   8554809.0        513.0      821.0   1334.0
# 7   11/05/2019    11718319.0   8555630.0       1524.0      772.0   2296.0
# 8   11/05/2019    11719843.0   8556402.0        540.0      855.0   1395.0
# 9   11/06/2019    11720383.0   8557257.0       1483.0      780.0   2263.0
# 10  11/06/2019    11721866.0   8558037.0        544.0      907.0   1451.0
# 11  11/07/2019    11722410.0   8558944.0       1488.0      741.0   2229.0
# 12  11/07/2019    11723898.0   8559685.0        503.0      785.0   1288.0
# 13  11/08/2019    11724401.0   8560470.0       1486.0      772.0   2258.0
# 14  11/08/2019    11725887.0   8561242.0        349.0      413.0    762.0
# 15  11/09/2019    11726236.0   8561655.0       1027.0      867.0   1894.0
# 16  11/09/2019    11727263.0   8562522.0        294.0      266.0    560.0
# 17  11/10/2019    11727557.0   8562788.0        891.0      720.0   1611.0
# 18  11/10/2019    11728448.0   8563508.0        425.0      738.0   1163.0
# 19  11/11/2019    11728873.0   8564246.0       1347.0      758.0   2105.0
# 20  11/11/2019    11730220.0   8565004.0        542.0      831.0   1373.0
# 21  11/12/2019    11730762.0   8565835.0       1435.0      692.0   2127.0
# 22  11/12/2019    11732197.0   8566527.0        527.0      834.0   1361.0
# 23  11/13/2019    11732724.0   8567361.0       1437.0      732.0   2169.0
# 24  11/13/2019    11734161.0   8568093.0        560.0      828.0   1388.0
# 25  11/14/2019    11734721.0   8568921.0       1450.0      716.0   2166.0
# 26  11/14/2019    11736171.0   8569637.0        508.0      803.0   1311.0
# 27  11/15/2019    11736679.0   8570440.0       1428.0      738.0   2166.0
# 28  11/15/2019    11738107.0   8571178.0        302.0      371.0    673.0
# 29  11/16/2019    11738409.0   8571549.0       1054.0      795.0   1849.0
# 30  11/16/2019    11739463.0   8572344.0        245.0      269.0    514.0
# 31  11/17/2019    11739708.0   8572613.0        789.0      587.0   1376.0
# 32  11/17/2019    11740497.0   8573200.0        482.0      862.0   1344.0
# 33  11/18/2019    11740979.0   8574062.0       1406.0      723.0   2129.0
# 34  11/18/2019    11742385.0   8574785.0        534.0      928.0   1462.0
# 35  11/19/2019    11742919.0   8575713.0       1499.0      902.0   2401.0
#
#    ZIPCODE  ZIPCODE_AGI
# 1      NaN          NaN
# 2      NaN          NaN
# 3      NaN          NaN
# 4      NaN          NaN
# 5      NaN          NaN
# 6      NaN          NaN
# 7      NaN          NaN
# 8      NaN          NaN
# 9      NaN          NaN
# 10     NaN          NaN
# 11     NaN          NaN
# 12     NaN          NaN
# 13     NaN          NaN
# 14     NaN          NaN
# 15     NaN          NaN
# 16     NaN          NaN
# 17     NaN          NaN
# 18     NaN          NaN
# 19     NaN          NaN
# 20     NaN          NaN
# 21     NaN          NaN
# 22     NaN          NaN
# 23     NaN          NaN
# 24     NaN          NaN
# 25     NaN          NaN
# 26     NaN          NaN
# 27     NaN          NaN
# 28     NaN          NaN
# 29     NaN          NaN
# 30     NaN          NaN
# 31     NaN          NaN
# 32     NaN          NaN
# 33     NaN          NaN
# 34     NaN          NaN
# 35     NaN          NaN

# %% [markdown]
# Let's filter by one station...

# %%
# mask = df_turnstiles.STATION == '34 ST-PENN STA'
# df_turnstiles[mask].head(20)

# %%
# df_ampm.groupby('STATION').agg(sum).sort_values("TRAFFIC", ascending=False).head(10)

# %%
# mask = df_ampm.STATION == '34 ST-PENN STA'
# df_ampm[mask]

# %%
# import json
# station_zips = json.load(open("data/station_zips.json", "r"))

# %%
# df_ampm['ZIPCODE'] = df_ampm['STATION'].map(station_zips)
# df_ampm.sample(50)

# %%
# station_agis = dict(zip(df_turnstiles['STATION'], df_turnstiles['ZIPCODE_AGI']))

# %%
# station_agis

# %%
# df_ampm['ZIPCODE_AGI'] = df_ampm['STATION'].map(station_agis)

# %%
# df_ampm.sample(20)

# %%
df_ampm.groupby(["STATION"]).agg(sum).sort_values("TRAFFIC", ascending=False).head(10)
# Out:
#                       ENTRIES         EXITS  PREV_ENTRIES    PREV_EXITS  \
# STATION
# 23 ST            455928240188  392699599033  4.559358e+11  3.927038e+11
# 34 ST-PENN STA   349522634781  295780285302  3.496264e+11  2.957792e+11
# GRD CNTRL-42 ST  246721312455  349337922842  2.467207e+11  3.493376e+11
# 34 ST-HERALD SQ  402869841392  549231786266  4.028699e+11  5.492310e+11
# 14 ST-UNION SQ    15452091906    8518147149  1.545125e+10  8.517386e+09
# TIMES SQ-42 ST   605308956566  472890952606  6.053084e+11  4.728903e+11
# FULTON ST        352830918591  446832202070  3.528304e+11  4.468314e+11
# 59 ST            134031133412   87093613207  1.340307e+11  8.709311e+10
# 96 ST             82401913267    7113448616  8.240137e+10  7.112833e+09
# CANAL ST         349090843413  342922973913  3.490906e+11  3.429225e+11
#
#                  TMP_ENTRIES  TMP_EXITS    TRAFFIC   ZIPCODE_AGI
# STATION
# 23 ST              1210802.0  1092580.0  2303382.0  1.346576e+10
# 34 ST-PENN STA      895644.0  1250075.0  2145719.0  0.000000e+00
# GRD CNTRL-42 ST     992300.0   887092.0  1879392.0  0.000000e+00
# 34 ST-HERALD SQ     796448.0   835936.0  1632384.0  1.613071e+09
# 14 ST-UNION SQ      844847.0   761596.0  1606443.0  4.546414e+09
# TIMES SQ-42 ST      892350.0   635912.0  1528262.0  2.640326e+09
# FULTON ST           562871.0   776994.0  1339865.0  0.000000e+00
# 59 ST               479908.0   691139.0  1171047.0  0.000000e+00
# 96 ST               540377.0   615304.0  1155681.0  1.122239e+09
# CANAL ST            637975.0   505804.0  1143779.0  6.175548e+09
