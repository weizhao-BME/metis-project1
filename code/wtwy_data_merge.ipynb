# %% [markdown]
# ## Data Merging
#
# This notebook covers how we gathered & cleaned our data from the various sources (New York MTA, Google Maps data). The code here is included in **clean2.py** in order to easily ready the data for analysis in other Jupyter Notebooks.
#
# The intent here is to prepare this dataset for visualization, particularly to create our map figures.
#
# This file:
# - adds the ``lat`` and ``lon`` columns to our dataFrames(from ``df_turnstiles``).
# - adds ``zipcode`` to our dataFrames
# - generates adjusted gross income (agi) by NYC zipcode using google APIs, and insert ``adj_gross_inc`` into ``df_turnstiles``
# - adds in necesarry geopandas shape columns to ``df_turnstiles`` that will allow the geodataframe to be visualized as a map of new york city
#
# It also pulls geolocation data from Google (using its ``geocode api``). This allows us to add ``zipcode`` to our data in order to filter by **AGI (Adjusted Gross Income)**, which is pulled from US Census today.

# %%
import numpy as np
import pandas as pd
import datetime as dt
import googlemaps
import requests

# %%
# this cell not working - can't import the file we're trying to generate

# from clean2 import *
# df_turnstiles, df_ampm, df_dailytraffic = data_wrangling()

# %% [markdown]
# Download MTA Data

# %%
url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"

# gather the week numbers of the data we want to pull from above urls
week_nums=[191228, 191221, 191214, 191207, 191130, 191123, 191116, 191109]
dfs = []

for week_num in week_nums:
    file_url = url.format(week_num)
    dfs.append(pd.read_csv(file_url, parse_dates=[["DATE", "TIME"]], keep_date_col=True))
    
df_turnstiles = pd.concat(dfs)
df_turnstiles.head(5)
# Out:
#             DATE_TIME   C/A  UNIT       SCP STATION LINENAME DIVISION  \
# 0 2019-12-21 03:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 1 2019-12-21 07:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 2 2019-12-21 11:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 3 2019-12-21 15:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 4 2019-12-21 19:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
#
#          DATE      TIME        DESC  ENTRIES  \
# 0  12/21/2019  03:00:00     REGULAR  7318040
# 1  12/21/2019  07:00:00     REGULAR  7318049
# 2  12/21/2019  11:00:00  RECOVR AUD  7318101
# 3  12/21/2019  15:00:00     REGULAR  7318263
# 4  12/21/2019  19:00:00     REGULAR  7318559
#
#    EXITS
# 0                                            2480587
# 1                                            2480598
# 2                                            2480680
# 3                                            2480763
# 4                                            2480823

# %% [markdown]
# An important note about this dataFrame:
# - The ``ENTRIES`` and ``EXITS`` columns are **cumulative**. In order for us to analyze AMPM traffic, we need to convert these columns from cumulative to hourly (in 4 hour increments, since that's how the data is formatted).
#     - before we can do that, we need to remove some rows that were added as a result of an audit (can think of these as corrections). There is a relatively small amount of them (about 7k of 1.63M rows using the above weeks.)

# %%
mask = df_turnstiles.DESC == 'RECOVR AUD'
df_turnstiles[mask].shape, df_turnstiles.shape
# Out:
# ((7102, 12), (1649098, 12))

# %% [markdown]
# Now let's get rid of the rows where ``turnstiles_df.DESC == 'RECOVR AUD'``. To do this, we will sort the rows so that the correct entry will come before the 'RECOVR AUD' entry. Then, we can apply the ``drop_duplicates`` dataFrame method to get rid of those rows.
#
# Then, since we've removed all rows where ``DESC`` is not ``'REGULAR'``, we can drop the column entirely.

# %%
df_turnstiles.sort_values(
            ["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"],
            inplace=True,
            ascending=False)

# keeps top row, deletes others
df_turnstiles.drop_duplicates(
    subset=["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"], inplace=True
)

# remove DESC column
df_turnstiles = df_turnstiles.drop(["DESC"], axis=1, errors="ignore")

df_turnstiles.head(5)
# Out:
#                  DATE_TIME    C/A  UNIT       SCP        STATION LINENAME  \
# 206706 2019-12-27 20:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206705 2019-12-27 16:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206704 2019-12-27 12:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206703 2019-12-27 08:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206702 2019-12-27 04:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#
#        DIVISION        DATE      TIME  ENTRIES  \
# 206706      RIT  12/27/2019  20:00:00     5554
# 206705      RIT  12/27/2019  16:00:00     5554
# 206704      RIT  12/27/2019  12:00:00     5554
# 206703      RIT  12/27/2019  08:00:00     5554
# 206702      RIT  12/27/2019  04:00:00     5554
#
#         EXITS
# 206706                                                420
# 206705                                                420
# 206704                                                420
# 206703                                                420
# 206702                                                420

# %% [markdown]
# Great, now we can see that there is no more DESC column.
#
# As you can see in the output of the below cell, the ``EXITS`` column has a lot of spaces after it. Let's fix that so we can easily select this column in the future.

# %%
df_turnstiles.columns
# Out:
# Index(['DATE_TIME', 'C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION',
#        'DATE', 'TIME', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
df_turnstiles.rename(columns={"EXITS                                                               ": "EXITS"},
            inplace=True)

# %% [markdown]
# Now, let's add the AMPM column.

# %%
df_turnstiles["AMPM"] = (pd.DatetimeIndex(df_turnstiles["TIME"]).strftime("%r").str[-2:])
df_turnstiles.head(3)
# Out:
#                  DATE_TIME    C/A  UNIT       SCP        STATION LINENAME  \
# 206706 2019-12-27 20:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206705 2019-12-27 16:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206704 2019-12-27 12:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#
#        DIVISION        DATE      TIME  ENTRIES  EXITS AMPM
# 206706      RIT  12/27/2019  20:00:00     5554    420   PM
# 206705      RIT  12/27/2019  16:00:00     5554    420   PM
# 206704      RIT  12/27/2019  12:00:00     5554    420   PM

# %% [markdown]
# And day name.

# %%
df_turnstiles["DAY_NAME"] = pd.to_datetime(df_turnstiles["DATE"]).dt.day_name()
df_turnstiles.head(3)
# Out:
#                  DATE_TIME    C/A  UNIT       SCP        STATION LINENAME  \
# 206706 2019-12-27 20:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206705 2019-12-27 16:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206704 2019-12-27 12:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#
#        DIVISION        DATE      TIME  ENTRIES  EXITS AMPM DAY_NAME
# 206706      RIT  12/27/2019  20:00:00     5554    420   PM   Friday
# 206705      RIT  12/27/2019  16:00:00     5554    420   PM   Friday
# 206704      RIT  12/27/2019  12:00:00     5554    420   PM   Friday

# %% [markdown]
# We eventually want to add the adjusted gross income of each station. To get that, we need zipcode. And to get zipcode, we will to take the lat/lon data provided in MTA's station data and pass it to Google's **geocode** API.

# %%
# Read in mta station's zipcode and income data into ``df_turnstiles``
mta_station_info = pd.read_csv("http://web.mta.info/developers/data/nyct/subway/Stations.csv")
mta_station_info.rename(columns={'Stop Name': 'STATION', 'GTFS Latitude': 'Lat', 'GTFS Longitude': 'Lon'}, inplace=True)

mta_station_info.head()
# Out:
#    Station ID  Complex ID GTFS Stop ID Division     Line  \
# 0           1           1          R01      BMT  Astoria
# 1           2           2          R03      BMT  Astoria
# 2           3           3          R04      BMT  Astoria
# 3           4           4          R05      BMT  Astoria
# 4           5           5          R06      BMT  Astoria
#
#                 STATION Borough Daytime Routes Structure        Lat  \
# 0  Astoria-Ditmars Blvd       Q            N W  Elevated  40.775036
# 1          Astoria Blvd       Q            N W  Elevated  40.770258
# 2                 30 Av       Q            N W  Elevated  40.766779
# 3              Broadway       Q            N W  Elevated  40.761820
# 4                 36 Av       Q            N W  Elevated  40.756804
#
#          Lon   North Direction Label South Direction Label  ADA ADA Notes
# 0 -73.912034                     NaN             Manhattan    0       NaN
# 1 -73.917843            Ditmars Blvd             Manhattan    1       NaN
# 2 -73.921479  Astoria - Ditmars Blvd             Manhattan    0       NaN
# 3 -73.925508  Astoria - Ditmars Blvd             Manhattan    0       NaN
# 4 -73.929575  Astoria - Ditmars Blvd             Manhattan    0       NaN

# %% [markdown]
# Nice! Now we have the station data...but still no zipcode. Let's get the station names and let Google do the rest.
#
# **NOTE**: This will take some time. Go get yourself a drink!

# %%
import googlemaps

# you will need to get your own API Key, this API key will not work for you.
# get your own at: https://developers.google.com/maps/documentation/geocoding/start
gmaps = googlemaps.Client(key='AIzaSyAn-enZAKGfjRe3WguahiEy1K4QwB9xO2s') 

#initialize dictionary to store zipcodes in
station_zips = {}
mta_station_names = list(mta_station_info.STATION.unique())

for station in mta_station_names:
    address = station + ' Station New York City, NY'
    geocode_result = gmaps.geocode(address)
    try:
        zipcode = geocode_result[0]['address_components'][6]['long_name']
        if len(zipcode) == 5:
            station_zips[station.upper()] = str(zipcode) 
    except:
        continue

# %%
station_zips
# Out:
# {'ASTORIA-DITMARS BLVD': '11105',
#  '30 AV': '11102',
#  '36 AV': '11106',
#  '39 AV-DUTCH KILLS': '11101',
#  'LEXINGTON AV/59 ST': '10065',
#  '5 AV/59 ST': '10019',
#  '57 ST-7 AV': '10106',
#  '49 ST': '10019',
#  'TIMES SQ-42 ST': '10018',
#  '34 ST-HERALD SQ': '10001',
#  '28 ST': '10001',
#  '23 ST': '10011',
#  '14 ST-UNION SQ': '10003',
#  '8 ST-NYU': '10003',
#  'PRINCE ST': '10012',
#  'CANAL ST': '10013',
#  'CITY HALL': '10013',
#  'CORTLANDT ST': '10007',
#  'RECTOR ST': '10006',
#  'COURT ST': '11201',
#  'JAY ST-METROTECH': '11201',
#  'DEKALB AV': '11217',
#  'UNION ST': '11215',
#  '4 AV-9 ST': '11215',
#  'PROSPECT AV': '11215',
#  '36 ST': '10012',
#  '53 ST': '10022',
#  'BAY RIDGE AV': '11220',
#  'BAY RIDGE-95 ST': '11209',
#  '7 AV': '10019',
#  'PARKSIDE AV': '11226',
#  'CHURCH AV': '11226',
#  'BEVERLEY RD': '11226',
#  'CORTELYOU RD': '11226',
#  'NEWKIRK PLAZA': '11226',
#  'AVENUE H': '11230',
#  'AVENUE J': '11230',
#  'AVENUE M': '11230',
#  'KINGS HWY': '11229',
#  'AVENUE U': '11223',
#  'NECK RD': '11229',
#  'SHEEPSHEAD BAY': '11235',
#  'BRIGHTON BEACH': '11235',
#  'OCEAN PKWY': '11235',
#  'W 8 ST-NY AQUARIUM': '11224',
#  'CONEY ISLAND-STILLWELL AV': '11224',
#  '9 AV': '11219',
#  '50 ST': '10019',
#  '55 ST': '11219',
#  '62 ST': '11219',
#  '71 ST': '11228',
#  '79 ST': '10024',
#  '18 AV': '11230',
#  '20 AV': '11204',
#  'BAY PKWY': '11214',
#  '25 AV': '11214',
#  'BAY 50 ST': '11214',
#  'NEW UTRECHT AV': '11219',
#  '121 ST': '11418',
#  '111 ST': '11418',
#  '104 ST': '11418',
#  'WOODHAVEN BLVD': '11373',
#  '75 ST-ELDERTS LN': '11421',
#  'CYPRESS HILLS': '11208',
#  'CRESCENT ST': '11106',
#  'NORWOOD AV': '11208',
#  'CLEVELAND ST': '11208',
#  'VAN SICLEN AV': '11207',
#  'ALABAMA AV': '11207',
#  'CHAUNCEY ST': '11207',
#  'HALSEY ST': '11237',
#  'GATES AV': '11221',
#  'KOSCIUSZKO ST': '11221',
#  'LORIMER ST': '11211',
#  'HEWES ST': '11211',
#  'MARCY AV': '11211',
#  'DELANCEY ST-ESSEX ST': '10002',
#  'BOWERY': '10002',
#  'CHAMBERS ST': '10007',
#  'BROAD ST': '10005',
#  'MIDDLE VILLAGE-METROPOLITAN AV': '11381',
#  'FOREST AV': '11385',
#  'SENECA AV': '11385',
#  'MYRTLE-WYCKOFF AVS': '11237',
#  'KNICKERBOCKER AV': '11237',
#  'CENTRAL AV': '11221',
#  '6 AV': '10011',
#  '14 ST-UNION SQ.': '10003',
#  '3 AV': '10003',
#  'BEDFORD AV': '11211',
#  'GRAHAM AV': '11211',
#  'GRAND ST': '11211',
#  'MORGAN AV': '11237',
#  'WILSON AV': '11207',
#  'BUSHWICK AV-ABERDEEN ST': '11207',
#  'ATLANTIC AV': '11207',
#  'SUTTER AV': '11207',
#  'LIVONIA AV': '11212',
#  'NEW LOTS AV': '11207',
#  'EAST 105 ST': '10029',
#  'CANARSIE-ROCKAWAY PKWY': '11236',
#  'FRANKLIN AV': '10013',
#  'PARK PL': '10007',
#  'BOTANIC GARDEN': '10458',
#  'INWOOD-207 ST': '10034',
#  'DYCKMAN ST': '10034',
#  '181 ST': '10033',
#  '168 ST': '10032',
#  '163 ST-AMSTERDAM AV': '10032',
#  '155 ST': '10039',
#  '145 ST': '10031',
#  '135 ST': '10030',
#  '116 ST': '10035',
#  'CATHEDRAL PKWY (110 ST)': '10026',
#  '103 ST': '10025',
#  '96 ST': '10029',
#  '81 ST-MUSEUM OF NATURAL HISTORY': '10024',
#  '72 ST': '10023',
#  '34 ST-PENN STATION': '10001',
#  '14 ST': '10011',
#  'SPRING ST': '10012',
#  'WORLD TRADE CENTER': '10007',
#  'HOYT-SCHERMERHORN STS': '11201',
#  'LAFAYETTE AV': '11217',
#  'CLINTON-WASHINGTON AVS': '11238',
#  'NOSTRAND AV': '11225',
#  'KINGSTON-THROOP AVS': '11213',
#  'UTICA AV': '11213',
#  'RALPH AV': '11233',
#  'ROCKAWAY AV': '11224',
#  'LIBERTY AV': '11207',
#  'SHEPHERD AV': '11208',
#  'EUCLID AV': '11208',
#  'GRANT AV': '11208',
#  '80 ST': '11417',
#  '88 ST': '11417',
#  'ROCKAWAY BLVD': '11417',
#  'OZONE PARK-LEFFERTS BLVD': '11419',
#  'AQUEDUCT RACETRACK': '11417',
#  'BROAD CHANNEL': '11693',
#  'BEACH 90 ST': '11693',
#  'BEACH 98 ST': '11694',
#  'BEACH 105 ST': '11694',
#  'ROCKAWAY PARK-BEACH 116 ST': '11694',
#  'BEACH 67 ST': '11692',
#  'BEACH 60 ST': '11692',
#  'BEACH 44 ST': '11691',
#  'BEACH 36 ST': '11691',
#  'FAR ROCKAWAY-MOTT AV': '11691',
#  'NORWOOD-205 ST': '10467',
#  'BEDFORD PARK BLVD': '10468',
#  'KINGSBRIDGE RD': '10468',
#  '182-183 STS': '10453',
#  'TREMONT AV': '10460',
#  '174-175 STS': '10453',
#  '167 ST': '10452',
#  '21 ST-QUEENSBRIDGE': '11101',
#  'ROOSEVELT ISLAND': '10044',
#  'LEXINGTON AV/63 ST': '10065',
#  '57 ST': '10019',
#  '47-50 STS-ROCKEFELLER CTR': '10020',
#  '42 ST-BRYANT PK': '10018',
#  '2 AV': '10003',
#  'EAST BROADWAY': '10002',
#  'BERGEN ST': '11201',
#  '15 ST-PROSPECT PARK': '11215',
#  'DITMAS AV': '11218',
#  'AVENUE I': '11230',
#  'AVENUE N': '11230',
#  'AVENUE P': '11223',
#  'AVENUE X': '11223',
#  '169 ST': '11432',
#  'PARSONS BLVD': '11432',
#  '75 AV': '11375',
#  'FOREST HILLS-71 AV': '11375',
#  '67 AV': '11375',
#  '63 DR-REGO PARK': '11374',
#  'GRAND AV-NEWTOWN': '11373',
#  'ELMHURST AV': '11372',
#  '65 ST': '11377',
#  'NORTHERN BLVD': '11377',
#  '46 ST': '11103',
#  'QUEENS PLAZA': '11101',
#  'COURT SQ-23 ST': '11101',
#  'LEXINGTON AV/53 ST': '10022',
#  '5 AV/53 ST': '10022',
#  'SUTPHIN BLVD-ARCHER AV-JFK AIRPORT': '11435',
#  'JAMAICA-VAN WYCK': '11418',
#  'COURT SQ': '11101',
#  '21 ST': '11101',
#  'GREENPOINT AV': '11222',
#  'NASSAU AV': '11222',
#  'METROPOLITAN AV': '11381',
#  'MYRTLE-WILLOUGHBY AVS': '11206',
#  'BEDFORD-NOSTRAND AVS': '11205',
#  'CLASSON AV': '11238',
#  'VAN CORTLANDT PARK-242 ST': '10471',
#  '238 ST': '10463',
#  '231 ST': '10463',
#  'MARBLE HILL-225 ST': '10034',
#  '215 ST': '10034',
#  '207 ST': '10034',
#  '168 ST-WASHINGTON HTS': '10032',
#  '157 ST': '10032',
#  '137 ST-CITY COLLEGE': '10031',
#  '116 ST-COLUMBIA UNIVERSITY': '10027',
#  '66 ST-LINCOLN CENTER': '10023',
#  '18 ST': '10011',
#  'CHRISTOPHER ST-SHERIDAN SQ': '10014',
#  'FRANKLIN ST': '10013',
#  'WTC CORTLANDT': '10006',
#  'SOUTH FERRY': '10004',
#  'PARK PLACE': '10007',
#  'WALL ST': '10006',
#  'CLARK ST': '11201',
#  'HOYT ST': '11201',
#  'NEVINS ST': '11217',
#  'GRAND ARMY PLAZA': '11238',
#  'FRANKLIN AVENUE-MEDGAR EVERS COLLEGE': '11225',
#  'KINGSTON AV': '11213',
#  'CROWN HTS-UTICA AV': '11213',
#  'SUTTER AV-RUTLAND RD': '11212',
#  'SARATOGA AV': '11212',
#  'JUNIUS ST': '11212',
#  'PENNSYLVANIA AV': '11207',
#  'PRESIDENT STREET-MEDGAR EVERS COLLEGE': '11225',
#  'STERLING ST': '11225',
#  'WINTHROP ST': '11225',
#  'BEVERLY RD': '11226',
#  'PELHAM BAY PARK': '10461',
#  'BUHRE AV': '10461',
#  'MIDDLETOWN RD': '10461',
#  'WESTCHESTER SQ-E TREMONT AV': '10461',
#  'ZEREGA AV': '10461',
#  'CASTLE HILL AV': '10462',
#  'PARKCHESTER': '10472',
#  'ST LAWRENCE AV': '10472',
#  'MORRISON AV-SOUNDVIEW': '10472',
#  'ELDER AV': '10472',
#  'WHITLOCK AV': '10459',
#  'HUNTS POINT AV': '10474',
#  'LONGWOOD AV': '10455',
#  "E 143 ST-ST MARY'S ST": '10454',
#  'CYPRESS AV': '10454',
#  'BROOK AV': '10454',
#  '3 AV-138 ST': '10454',
#  'MOSHOLU PKWY': '10467',
#  'BEDFORD PARK BLVD-LEHMAN COLLEGE': '10468',
#  '183 ST': '10453',
#  'BURNSIDE AV': '10453',
#  '176 ST': '10453',
#  'MT EDEN AV': '10452',
#  '149 ST-GRAND CONCOURSE': '10451',
#  '138 ST-GRAND CONCOURSE': '10451',
#  '110 ST': '10029',
#  '68 ST-HUNTER COLLEGE': '10021',
#  'GRAND CENTRAL-42 ST': '10017',
#  '33 ST': '10001',
#  'ASTOR PL': '10003',
#  'BLEECKER ST': '10012',
#  'BROOKLYN BRIDGE-CITY HALL': '10013',
#  'BOWLING GREEN': '10004',
#  'WAKEFIELD-241 ST': '10470',
#  '233 ST': '10466',
#  '225 ST': '10466',
#  '219 ST': '10467',
#  'GUN HILL RD': '10467',
#  'BURKE AV': '10467',
#  'ALLERTON AV': '10467',
#  'BRONX PARK EAST': '10462',
#  'E 180 ST': '10460',
#  'WEST FARMS SQ-E TREMONT AV': '10460',
#  '174 ST': '10460',
#  'FREEMAN ST': '10459',
#  'SIMPSON ST': '10459',
#  'INTERVALE AV': '10459',
#  'JACKSON AV': '10455',
#  '3 AV-149 ST': '10455',
#  'HARLEM-148 ST': '10039',
#  'CENTRAL PARK NORTH (110 ST)': '10026',
#  'EASTCHESTER-DYRE AV': '10466',
#  'BAYCHESTER AV': '10469',
#  'MORRIS PARK': '10462',
#  'FLUSHING-MAIN ST': '11354',
#  'METS-WILLETS POINT': '11368',
#  'JUNCTION BLVD': '11368',
#  '90 ST-ELMHURST AV': '11372',
#  '69 ST': '11377',
#  'WOODSIDE-61 ST': '11377',
#  '52 ST': '11377',
#  '46 ST-BLISS ST': '11104',
#  '40 ST-LOWERY ST': '11104',
#  '33 ST-RAWSON ST': '11101',
#  'QUEENSBORO PLAZA': '11101',
#  'HUNTERS POINT AV': '11101',
#  'VERNON BLVD-JACKSON AV': '11101',
#  'TOMPKINSVILLE': '10304',
#  'STAPLETON': '10304',
#  'CLIFTON': '10304',
#  'GRASMERE': '10305',
#  'OLD TOWN': '10305',
#  'JEFFERSON AV': '10306',
#  'GRANT CITY': '10306',
#  'NEW DORP': '10306',
#  'OAKWOOD HEIGHTS': '10306',
#  'BAY TERRACE': '10306',
#  'GREAT KILLS': '10308',
#  'ELTINGVILLE': '10312',
#  'ANNADALE': '10312',
#  "PRINCE'S BAY": '10309',
#  'PLEASANT PLAINS': '10309',
#  'RICHMOND VALLEY': '10309',
#  'TOTTENVILLE': '10307',
#  'ARTHUR KILL': '10307'}

# %% [markdown]
# ``station_zips`` now contains the zip codes for each station. Some are missing - that's because some zip codes in New York are so small that Google doesn't have the data for them.
#
# Now let's add that to our dataFrames!

# %%
mta_station_info['ZIPCODE'] = mta_station_info['STATION'].str.upper().map(station_zips)
df_turnstiles['ZIPCODE'] = df_turnstiles['STATION'].map(station_zips)
df_turnstiles.sample(10)
# Out:
#                  DATE_TIME    C/A  UNIT       SCP          STATION  \
# 168643 2019-12-02 23:22:00  R262A  R195  04-00-03  161/YANKEE STAD
# 204007 2019-11-19 23:00:00   S101  R070  00-00-06       ST. GEORGE
# 85939  2019-11-15 16:00:00   N333  R141  01-00-01  FOREST HILLS 71
# 140227 2019-12-19 07:00:00   R145  R032  00-06-02   TIMES SQ-42 ST
# 146921 2019-12-23 00:00:00   R176  R169  00-00-00  137 ST CITY COL
# 203246 2019-11-07 20:00:00   R637  R451  00-00-02      WINTHROP ST
# 95457  2019-11-05 12:00:00  N414A  R316  01-06-00      FLUSHING AV
# 157596 2019-12-06 08:00:00   R231  R176  00-00-01            33 ST
# 36657  2019-11-30 23:00:00   H035  R348  00-00-02      ATLANTIC AV
# 42125  2019-12-22 03:00:00   J035  R008  00-00-03           111 ST
#
#             LINENAME DIVISION        DATE      TIME   ENTRIES    EXITS AMPM  \
# 168643           4BD      IRT  12/02/2019  23:22:00    107441    94120   PM
# 204007             1      SRT  11/19/2019  23:00:00   2096947     8380   PM
# 85939           EFMR      IND  11/15/2019  16:00:00    612633   195642   PM
# 140227  1237ACENQRSW      IRT  12/19/2019  07:00:00    707418   508512   AM
# 146921             1      IRT  12/23/2019  00:00:00  11030589  6867518   AM
# 203246            25      IRT  11/07/2019  20:00:00  18325387   755473   PM
# 95457              G      IND  11/05/2019  12:00:00   1752338  1637807   PM
# 157596             6      IRT  12/06/2019  08:00:00   4482580  2414849   AM
# 36657              L      BMT  11/30/2019  23:00:00   1764032   961138   PM
# 42125              J      BMT  12/22/2019  03:00:00   6954058  5062010   AM
#
#         DAY_NAME ZIPCODE  ZIPCODE_AGI
# 168643    Monday     NaN          NaN
# 204007   Tuesday     NaN          NaN
# 85939     Friday     NaN          NaN
# 140227  Thursday   10018    3964454.0
# 146921    Monday     NaN          NaN
# 203246  Thursday   11225    1755176.0
# 95457    Tuesday     NaN          NaN
# 157596    Friday   10001    2906435.0
# 36657   Saturday   11207    1650855.0
# 42125     Sunday   11418     840143.0

# %%
df_turnstiles['ZIPCODE'].iloc[213431]
# Out:
# '10472'

# %% [markdown]
# #### Adjusted gross income, AGI - first retrieve for the entire United States by zipcode

# %%
us_zips_agi = pd.read_csv("https://www.irs.gov/pub/irs-soi/18zpallagi.csv")
us_zips_agi.rename(columns={'A00100':'adj_gross_inc'}, inplace=True) # in 18zpallagi.csv, A00100 stands for AGI
us_zips_agi = us_zips_agi[['zipcode','adj_gross_inc']].groupby('zipcode').agg(sum) # group by zipcode and sum AGI

# %% [markdown]
# We can sort this zipcode/agi data into NYC zipcodes by joining the data with a list of nyc_zipcodes (ny_zips.csv)

# %%
nyc_zips = pd.read_csv("data/ny_zips.csv")
nyc_zips.dropna(axis=1, how='all', inplace=True)
nyc_agi_by_zip = nyc_zips.join(us_zips_agi, how='inner', on='zipcode')

# must capitalize col name & change from dtype 'object' to 'str' in order to merge into df_turnstiles
nyc_agi_by_zip.columns = nyc_agi_by_zip.columns.str.upper()
nyc_agi_by_zip['ZIPCODE'] = nyc_agi_by_zip.ZIPCODE.astype(str)

nyc_agi_by_zip.head(10)
# Out:
#   ZIPCODE       AREA  ADJ_GROSS_INC
# 0   10001  Manhattan      2906435.0
# 1   10002  Manhattan      2718913.0
# 2   10003  Manhattan      8191737.0
# 3   10004  Manhattan       944925.0
# 4   10005  Manhattan      2603668.0
# 5   10006  Manhattan       577145.0
# 6   10007  Manhattan      2910802.0
# 7   10009  Manhattan      2948597.0
# 8   10010  Manhattan      4542337.0
# 9   10011  Manhattan      9331779.0

# %%
nyc_agi_by_zip[['ZIPCODE', 'ADJ_GROSS_INC']].set_index('ZIPCODE').to_dict()['ADJ_GROSS_INC']
# Out:
# {'10001': 2906435.0,
#  '10002': 2718913.0,
#  '10003': 8191737.0,
#  '10004': 944925.0,
#  '10005': 2603668.0,
#  '10006': 577145.0,
#  '10007': 2910802.0,
#  '10009': 2948597.0,
#  '10010': 4542337.0,
#  '10011': 9331779.0,
#  '10012': 3646355.0,
#  '10013': 7947938.0,
#  '10014': 6795181.0,
#  '10016': 8000771.0,
#  '10017': 4417331.0,
#  '10018': 3964454.0,
#  '10019': 8005583.0,
#  '10021': 12798847.0,
#  '10022': 14226340.0,
#  '10023': 12391069.0,
#  '10024': 13806195.0,
#  '10025': 8028810.0,
#  '10026': 1440633.0,
#  '10027': 1972417.0,
#  '10028': 10128983.0,
#  '10029': 2022052.0,
#  '10030': 645026.0,
#  '10031': 1401061.0,
#  '10032': 1270384.0,
#  '10033': 1360083.0,
#  '10034': 1019289.0,
#  '10035': 833400.0,
#  '10036': 4568142.0,
#  '10037': 570270.0,
#  '10038': 1953888.0,
#  '10039': 586050.0,
#  '10040': 1037660.0,
#  '10044': 472585.0,
#  '10069': 1777529.0,
#  '10128': 12570244.0,
#  '10162': 203692.0,
#  '10280': 1047685.0,
#  '10282': 1442366.0,
#  '10301': 1369609.0,
#  '10302': 458236.0,
#  '10303': 594095.0,
#  '10304': 1515252.0,
#  '10305': 1278252.0,
#  '10306': 2132001.0,
#  '10307': 657079.0,
#  '10308': 1124965.0,
#  '10309': 1420600.0,
#  '10310': 776063.0,
#  '10312': 2582965.0,
#  '10314': 3085380.0,
#  '10451': 857426.0,
#  '10452': 1129896.0,
#  '10453': 1118282.0,
#  '10454': 488519.0,
#  '10455': 574656.0,
#  '10456': 1209535.0,
#  '10457': 997507.0,
#  '10458': 1116373.0,
#  '10459': 678052.0,
#  '10460': 826025.0,
#  '10461': 1346454.0,
#  '10462': 1795269.0,
#  '10463': 2432458.0,
#  '10464': 212670.0,
#  '10465': 1287456.0,
#  '10466': 1388485.0,
#  '10467': 1714750.0,
#  '10468': 1203575.0,
#  '10469': 1593018.0,
#  '10470': 435453.0,
#  '10471': 1390724.0,
#  '10472': 971500.0,
#  '10473': 1203457.0,
#  '10474': 155708.0,
#  '10475': 1153512.0,
#  '11004': 497011.0,
#  '11101': 2273198.0,
#  '11102': 1225616.0,
#  '11103': 1269650.0,
#  '11104': 1013072.0,
#  '11105': 1347282.0,
#  '11106': 1391829.0,
#  '11109': 700625.0,
#  '11201': 7714299.0,
#  '11203': 1679309.0,
#  '11204': 1935543.0,
#  '11205': 1529774.0,
#  '11206': 1771285.0,
#  '11207': 1650855.0,
#  '11208': 1586724.0,
#  '11209': 2811643.0,
#  '11210': 2348707.0,
#  '11211': 2684922.0,
#  '11212': 1344174.0,
#  '11213': 1378248.0,
#  '11214': 1930773.0,
#  '11215': 5454584.0,
#  '11216': 1830296.0,
#  '11217': 3143030.0,
#  '11218': 2212234.0,
#  '11219': 1635884.0,
#  '11220': 1748844.0,
#  '11221': 1958838.0,
#  '11222': 2098579.0,
#  '11223': 2556150.0,
#  '11224': 910704.0,
#  '11225': 1755176.0,
#  '11226': 2466184.0,
#  '11228': 1336182.0,
#  '11229': 2423575.0,
#  '11230': 2773769.0,
#  '11231': 2885921.0,
#  '11232': 618142.0,
#  '11233': 1471332.0,
#  '11234': 3023834.0,
#  '11235': 2567055.0,
#  '11236': 2301827.0,
#  '11237': 1030147.0,
#  '11238': 3353662.0,
#  '11239': 322447.0,
#  '11354': 1299395.0,
#  '11355': 1610782.0,
#  '11356': 589237.0,
#  '11357': 1898492.0,
#  '11358': 1220462.0,
#  '11360': 1004624.0,
#  '11361': 1014165.0,
#  '11362': 774948.0,
#  '11363': 458581.0,
#  '11364': 1300224.0,
#  '11365': 1279603.0,
#  '11366': 490003.0,
#  '11367': 1312965.0,
#  '11368': 1609584.0,
#  '11369': 732524.0,
#  '11370': 687350.0,
#  '11372': 1791324.0,
#  '11373': 1951391.0,
#  '11374': 1606102.0,
#  '11375': 3714463.0,
#  '11377': 2133352.0,
#  '11378': 1034753.0,
#  '11379': 1335108.0,
#  '11385': 2525905.0,
#  '11411': 604233.0,
#  '11412': 945365.0,
#  '11413': 1147871.0,
#  '11414': 1018439.0,
#  '11415': 706738.0,
#  '11416': 490762.0,
#  '11417': 724600.0,
#  '11418': 840143.0,
#  '11419': 924466.0,
#  '11420': 1069765.0,
#  '11421': 921337.0,
#  '11422': 876114.0,
#  '11423': 812347.0,
#  '11426': 626861.0,
#  '11427': 754242.0,
#  '11428': 515246.0,
#  '11429': 633574.0,
#  '11432': 1430777.0,
#  '11433': 673077.0,
#  '11434': 1548972.0,
#  '11435': 1225636.0,
#  '11436': 435964.0,
#  '11691': 1033194.0,
#  '11692': 393888.0,
#  '11693': 319792.0,
#  '11694': 850523.0,
#  '11697': 253659.0}

# %% [markdown]
# Great! Now we can add AGI to our turnstiles DataFrames. Let's do that now.

# %%
# THIS CELL WORKS IN JNB- do not change
zipcode_agis = nyc_agi_by_zip[['ZIPCODE', 'ADJ_GROSS_INC']].set_index('ZIPCODE').to_dict()['ADJ_GROSS_INC']
df_turnstiles['ZIPCODE_AGI'] = df_turnstiles['ZIPCODE'].map(zipcode_agis)
df_turnstiles.sample(10)
# Out:
#                  DATE_TIME    C/A  UNIT       SCP          STATION LINENAME  \
# 8868   2019-12-27 04:00:00   A049  R088  02-03-00     CORTLANDT ST      RNW
# 70310  2019-11-06 07:00:00   N137  R354  00-06-01           104 ST        A
# 69208  2019-12-02 04:00:00   N131  R383  00-00-02            80 ST        A
# 47112  2019-12-16 23:00:00   N025  R102  01-00-00           125 ST     ACBD
# 48931  2019-11-18 15:00:00   N043  R186  00-06-00            86 ST       BC
# ...                    ...    ...   ...       ...              ...      ...
# 164087 2019-11-10 07:00:00   R249  R179  01-00-06            86 ST      456
# 20094  2019-11-05 03:00:00   C003  R089  00-00-02  JAY ST-METROTEC        R
# 25326  2019-12-08 08:00:00   D002  R390  00-06-01             8 AV        N
# 95870  2019-11-22 15:00:00   N500  R020  00-06-00   47-50 STS ROCK     BDFM
# 120573 2019-12-26 11:18:45  PTH07  R550  00-00-06       CITY / BUS        1
#
#        DIVISION        DATE      TIME     ENTRIES      EXITS AMPM   DAY_NAME  \
# 8868        BMT  12/27/2019  04:00:00     1691836     271118   AM     Friday
# 70310       IND  11/06/2019  07:00:00  1681109400  978345590   AM  Wednesday
# 69208       IND  12/02/2019  04:00:00     3773395    1066443   AM     Monday
# 47112       IND  12/16/2019  23:00:00       61329      55450   PM     Monday
# 48931       IND  11/18/2019  15:00:00      373509      99580   PM     Monday
# ...         ...         ...       ...         ...        ...  ...        ...
# 164087      IRT  11/10/2019  07:00:00     1277087    2985517   AM     Sunday
# 20094       BMT  11/05/2019  03:00:00     3390143    1327564   AM    Tuesday
# 25326       BMT  12/08/2019  08:00:00           1         50   AM     Sunday
# 95870       IND  11/22/2019  15:00:00       31139      34868   PM     Friday
# 120573      PTH  12/26/2019  11:18:45      199621     248649   AM   Thursday
#
#        ZIPCODE  ZIPCODE_AGI
# 8868     10007    2910802.0
# 70310    11418     840143.0
# 69208    11417     724600.0
# 47112      NaN          NaN
# 48931      NaN          NaN
# ...        ...          ...
# 164087     NaN          NaN
# 20094      NaN          NaN
# 25326      NaN          NaN
# 95870      NaN          NaN
# 120573     NaN          NaN
#
# [100 rows x 15 columns]

# %% [markdown]
# Cool, now it's time to convert ENTRIES and EXITS columns from cumulative to it's change from previous value.
#
# We do this by shifting the previous values forward, then subtracting the previous values from the current ones.

# %%
df_turnstiles['ZIPCODE_AGI'] = df_turnstiles['STATION'].map(station_zips)
df_turnstiles.sample(40)
# Out:
#                  DATE_TIME    C/A  UNIT       SCP          STATION  \
# 117278 2019-11-29 18:06:46  PTH04  R551  00-00-01     GROVE STREET
# 107697 2019-11-11 04:00:00   N555  R423  00-00-02         AVENUE N
# 120430 2019-11-15 04:51:43  PTH11  R545  00-00-00      14TH STREET
# 169987 2019-12-26 19:00:00   R287  R244  00-00-00      BURNSIDE AV
# 2835   2019-11-18 19:00:00   A021  R032  01-00-01   TIMES SQ-42 ST
# 30861  2019-11-16 19:00:00   G011  R312  00-00-01  W 8 ST-AQUARIUM
# 66657  2019-12-19 23:00:00  N112A  R284  01-00-01  CLINTON-WASH AV
# 112599 2019-11-10 04:00:00   N700  R570  00-03-01      72 ST-2 AVE
# 144726 2019-12-26 20:00:00   R166  R167  02-00-02            86 ST
# 154883 2019-12-13 16:00:00   R221  R170  01-06-03   14 ST-UNION SQ
# 115080 2019-12-10 11:22:31  PTH01  R549  00-00-05  NEWARK HW BMEBE
# 24870  2019-12-09 08:00:00   D001  R390  01-00-02             8 AV
# 89048  2019-11-29 00:00:00  N338B  R128  00-00-01     SUTPHIN BLVD
# 41578  2019-11-21 23:00:00   J034  R007  00-00-02           104 ST
# 180181 2019-12-15 04:00:00   R412  R146  00-06-00   HUNTS POINT AV
# 3605   2019-12-17 19:00:00   A025  R023  01-03-02  34 ST-HERALD SQ
# 74503  2019-12-01 23:00:00   N206  R104  01-00-00           167 ST
# 36773  2019-11-23 04:00:00   H041  R152  00-05-00  CANARSIE-ROCKAW
# 102335 2019-11-19 07:00:00   N523  R300  00-00-03             2 AV
# 24865  2019-11-10 20:00:00   D002  R390  00-00-00             8 AV
# 168828 2019-11-27 23:00:00   R286  R309  00-00-01           176 ST
# 10357  2019-12-17 03:00:00   A055  R227  00-00-00        RECTOR ST
# 160052 2019-12-23 07:00:00   R238  R046  00-03-00  GRD CNTRL-42 ST
# 200241 2019-11-11 11:00:00   R635  R277  00-00-00     PRESIDENT ST
# 155378 2019-12-12 04:00:00  R226A  R131  03-05-01            23 ST
# 73351  2019-11-02 16:00:00   N194  R338  00-00-00      BEACH 36 ST
# 189667 2019-11-23 16:00:00   R532  R328  00-05-00  METS-WILLETS PT
# 159048 2019-11-18 15:00:00   R238  R046  00-03-03  GRD CNTRL-42 ST
# 22782  2019-11-13 19:00:00   C020  R233  00-00-02            53 ST
# 109560 2019-11-18 23:00:00   N601  R319  00-00-02  LEXINGTON AV/63
# 17847  2019-11-28 03:00:00  B024A  R211  02-00-04        KINGS HWY
# 36498  2019-12-02 11:00:00   H033  R313  00-00-01      BUSHWICK AV
# 99324  2019-11-23 23:00:00   N507  R023  00-03-02  34 ST-HERALD SQ
# 172591 2019-11-14 08:00:00   R312  R405  00-05-01       JACKSON AV
# 177582 2019-12-13 00:00:00   R406  R448  00-00-01  E 143/ST MARY'S
# 151730 2019-11-18 12:00:00   R206  R014  02-00-02        FULTON ST
# 196003 2019-11-22 06:38:38   R610  R057  00-04-04   ATL AV-BARCLAY
# 120736 2019-11-22 15:16:43  PTH11  R545  00-04-00      14TH STREET
# 35519  2019-11-30 07:00:00   H026  R137  00-03-03   MYRTLE-WYCKOFF
# 146584 2019-11-07 12:00:00   R170  R191  00-00-00           103 ST
#
#             LINENAME DIVISION        DATE      TIME     ENTRIES      EXITS  \
# 117278             1      PTH  11/29/2019  18:06:46       72548      83487
# 107697             F      IND  11/11/2019  04:00:00  1179021932    1551581
# 120430             1      PTH  11/15/2019  04:51:43      113674       4936
# 169987             4      IRT  12/26/2019  19:00:00      355731     270019
# 2835    ACENQRS1237W      BMT  11/18/2019  19:00:00     3804229    4416391
# 30861             FQ      BMT  11/16/2019  19:00:00     3168601    2593014
# 66657              C      IND  12/19/2019  23:00:00      678433    2532480
# 112599             Q      IND  11/10/2019  04:00:00     1625349    1870989
# 144726             1      IRT  12/26/2019  20:00:00     2857308    3348640
# 154883      456LNQRW      IRT  12/13/2019  16:00:00      387579     172098
# 115080             1      PTH  12/10/2019  11:22:31       22538       6080
# 24870              N      BMT  12/09/2019  08:00:00      127374     127072
# 89048              F      IND  11/29/2019  00:00:00     1345251     891081
# 41578             JZ      BMT  11/21/2019  23:00:00       16162      12469
# 180181             6      IRT  12/15/2019  04:00:00        1700          0
# 3605        BDFMNQRW      BMT  12/17/2019  19:00:00     1777563     867626
# 74503             BD      IND  12/01/2019  23:00:00      150885     115825
# 36773              L      BMT  11/23/2019  04:00:00        2420          0
# 102335             F      IND  11/19/2019  07:00:00     7325497    3145640
# 24865              N      BMT  11/10/2019  20:00:00       72177     226337
# 168828             4      IRT  11/27/2019  23:00:00       14148       5443
# 10357            NRW      BMT  12/17/2019  03:00:00     1227277     482142
# 160052         4567S      IRT  12/23/2019  07:00:00    16320944    6803940
# 200241            25      IRT  11/11/2019  11:00:00     3706367    5492490
# 155378             6      IRT  12/12/2019  04:00:00           2       1078
# 73351              A      IND  11/02/2019  16:00:00      794555    1296379
# 189667             7      IRT  11/23/2019  16:00:00     2342444     899213
# 159048         4567S      IRT  11/18/2019  15:00:00      252263     426952
# 22782              R      BMT  11/13/2019  19:00:00   101011188  134449304
# 109560             F      IND  11/18/2019  23:00:00    18430080   14112194
# 17847             BQ      BMT  11/28/2019  03:00:00     3940318    3325117
# 36498              L      BMT  12/02/2019  11:00:00     1708562     707219
# 99324       BDFMNQRW      IND  11/23/2019  23:00:00     4461896    3297362
# 172591            25      IRT  11/14/2019  08:00:00      789262     214351
# 177582             6      IRT  12/13/2019  00:00:00      769526     190239
# 151730      2345ACJZ      IRT  11/18/2019  12:00:00     1512597    3709786
# 196003     2345BDNQR      IRT  11/22/2019  06:38:38     1152721     127173
# 120736             1      PTH  11/22/2019  15:16:43        3928     136171
# 35519             LM      BMT  11/30/2019  07:00:00     4629841     377889
# 146584             1      IRT  11/07/2019  12:00:00     2411039     945659
#
#        AMPM   DAY_NAME ZIPCODE ZIPCODE_AGI
# 117278   PM     Friday     NaN         NaN
# 107697   AM     Monday   11230       11230
# 120430   AM     Friday     NaN         NaN
# 169987   PM   Thursday   10453       10453
# 2835     PM     Monday   10018       10018
# 30861    PM   Saturday     NaN         NaN
# 66657    PM   Thursday     NaN         NaN
# 112599   AM     Sunday     NaN         NaN
# 144726   PM   Thursday     NaN         NaN
# 154883   PM     Friday   10003       10003
# 115080   AM    Tuesday     NaN         NaN
# 24870    AM     Monday     NaN         NaN
# 89048    AM     Friday     NaN         NaN
# 41578    PM   Thursday   11418       11418
# 180181   AM     Sunday   10474       10474
# 3605     PM    Tuesday   10001       10001
# 74503    PM     Sunday   10452       10452
# 36773    AM   Saturday     NaN         NaN
# 102335   AM    Tuesday   10003       10003
# 24865    PM     Sunday     NaN         NaN
# 168828   PM  Wednesday   10453       10453
# 10357    AM    Tuesday   10006       10006
# 160052   AM     Monday     NaN         NaN
# 200241   AM     Monday     NaN         NaN
# 155378   AM   Thursday   10011       10011
# 73351    PM   Saturday   11691       11691
# 189667   PM   Saturday     NaN         NaN
# 159048   PM     Monday     NaN         NaN
# 22782    PM  Wednesday   10022       10022
# 109560   PM     Monday     NaN         NaN
# 17847    AM   Thursday   11229       11229
# 36498    AM     Monday     NaN         NaN
# 99324    PM   Saturday   10001       10001
# 172591   AM   Thursday   10455       10455
# 177582   AM     Friday     NaN         NaN
# 151730   PM     Monday     NaN         NaN
# 196003   AM     Friday     NaN         NaN
# 120736   PM     Friday     NaN         NaN
# 35519    AM   Saturday     NaN         NaN
# 146584   PM   Thursday   10025       10025

# %%
# group data by AMPM, taking the maximum entries/exits for each date 
ampm_station_group = df_turnstiles.groupby(["C/A", "UNIT", "SCP", "STATION", "ZIPCODE", "ZIPCODE_AGI", "DATE", "AMPM", "DAY_NAME"],
    as_index=False)

df_ampm = ampm_station_group.ENTRIES.max()
ampm_station_exits = ampm_station_group.EXITS.max()
df_ampm["EXITS"] = ampm_station_exits["EXITS"]

# create prev_date and prev_entries cols by shifting these columns forward one day
# if shifting date and entries, don't group by date
df_ampm[["PREV_DATE", "PREV_ENTRIES", "PREV_EXITS"]] = df_ampm.groupby(
    ["C/A", "UNIT", "SCP", "STATION", "ZIPCODE", "ZIPCODE_AGI", "AMPM"]
)[["DATE", "ENTRIES", "EXITS"]].apply(lambda grp: grp.shift(1))

# Drop the rows for the earliest date in the df, which are now NaNs for prev_date and prev_entries cols
df_ampm.dropna(subset=["PREV_DATE"], axis=0, inplace=True)

df_ampm.head()
# Out:
#     C/A  UNIT       SCP     STATION ZIPCODE  ZIPCODE_AGI        DATE AMPM  \
# 2  A006  R079  00-00-00  5 AV/59 ST   10019    8005583.0  11/03/2019   AM
# 3  A006  R079  00-00-00  5 AV/59 ST   10019    8005583.0  11/03/2019   PM
# 4  A006  R079  00-00-00  5 AV/59 ST   10019    8005583.0  11/04/2019   AM
# 5  A006  R079  00-00-00  5 AV/59 ST   10019    8005583.0  11/04/2019   PM
# 6  A006  R079  00-00-00  5 AV/59 ST   10019    8005583.0  11/05/2019   AM
#
#   DAY_NAME  ENTRIES    EXITS   PREV_DATE  PREV_ENTRIES  PREV_EXITS
# 2   Sunday  4099092  7058848  11/02/2019     4097957.0   7057072.0
# 3   Sunday  4099979  7060287  11/02/2019     4098923.0   7058586.0
# 4   Monday  4100128  7061222  11/03/2019     4099092.0   7058848.0
# 5   Monday  4101641  7063433  11/03/2019     4099979.0   7060287.0
# 6  Tuesday  4101898  7064433  11/04/2019     4100128.0   7061222.0

# %% [markdown]
# Alright, as we can see above, we now have ``PREV_ENTRIES`` and ``PREV_EXITS`` columns, and they seem mostly correct. However, there is a lot of data, and we noticed that sometimes ``PREV_ENTRIES`` > ``ENTRIES``. This shouldn't be...in fact, we determined that some stations were counting in reverse! In other cases, the variance to the previous count was hundreds of thousands, sometimes millions. We decided to cap these at 200,000 to maintain our data's integrity as best as possible.
#
# The below functions takes care of this for us for both ENTRIES and EXITS.

# %%
def add_counts(row, max_counter, column_name):
    """
    Takes:
        - max_counter is the maximum difference between entries/exits & their prev. row values that
    we will allow.
    column_name (string): which column to count
    """

    counter = row[column_name] - row[f"PREV_{column_name}"]
    if counter < 0:
        # Maybe counter is reversed?
        counter = -counter

    if counter > max_counter:
        # Maybe counter was reset to 0?
        # take the lower value as the counter for this row
        counter = min(row[column_name], row[f"PREV_{column_name}"])

    if counter > max_counter:
        # Check it again to make sure we're not still giving a counter that's too big
        return 0

    return counter

# %% [markdown]
# Alright, now let's apply this function to our dataFrames.

# %%
# we will use a 200k counter - anything more seems incorrect.
df_ampm["TMP_ENTRIES"] = df_ampm.apply(
    add_counts, axis=1, max_counter=200000, column_name='ENTRIES')

df_ampm["TMP_EXITS"] = df_ampm.apply(
    add_counts, axis=1, max_counter=200000, column_name='EXITS')

# %%
df_ampm.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE AMPM DAY_NAME  ENTRIES    EXITS  \
# 2  A002  R051  02-00-00   59 ST  11/03/2019   AM   Sunday  7257271  2459060
# 3  A002  R051  02-00-00   59 ST  11/03/2019   PM   Sunday  7258068  2459211
# 4  A002  R051  02-00-00   59 ST  11/04/2019   AM   Monday  7258268  2459570
# 5  A002  R051  02-00-00   59 ST  11/04/2019   PM   Monday  7259609  2459759
# 6  A002  R051  02-00-00   59 ST  11/05/2019   AM  Tuesday  7259800  2460102
#
#     PREV_DATE  PREV_ENTRIES  PREV_EXITS  TMP_ENTRIES  TMP_EXITS
# 2  11/02/2019     7256298.0   2458759.0        973.0      301.0
# 3  11/02/2019     7256982.0   2458965.0       1086.0      246.0
# 4  11/03/2019     7257271.0   2459060.0        997.0      510.0
# 5  11/03/2019     7258068.0   2459211.0       1541.0      548.0
# 6  11/04/2019     7258268.0   2459570.0       1532.0      532.0
