# %% [markdown]
# ## Data Merging
#
# This notebook covers how we gathered & cleaned our data from the various sources (New York MTA, Google Maps data, IRS Income). The code here is included in **clean2.py** in order to easily ready the data for analysis in other Jupyter Notebooks.
#
# The intent here is to prepare this dataset for visualization, particularly to create our map figures.
#
# It also pulls geolocation data from Google (using its ``geocode api``). This allows us to add ``zipcode`` to our data in order to filter by **AGI (Adjusted Gross Income)**, which is pulled from US Census today.

# %%
import numpy as np
import pandas as pd
import datetime as dt
import googlemaps
import requests

# %%
# this cell not working - can't import the file we're trying to generate

# from clean2 import *
# df_turnstiles, df_ampm, df_dailytraffic = data_wrangling()

# %% [markdown]
# Download MTA Data

# %%
url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"

# gather the week numbers of the data we want to pull from above urls
week_nums=[191228, 191221, 191214, 191207, 191130, 191123, 191116, 191109]
dfs = []

for week_num in week_nums:
    file_url = url.format(week_num)
    dfs.append(pd.read_csv(file_url, parse_dates=[["DATE", "TIME"]], keep_date_col=True))
    
df_turnstiles = pd.concat(dfs)
df_turnstiles.head(5)
# Out:
#             DATE_TIME   C/A  UNIT       SCP STATION LINENAME DIVISION  \
# 0 2019-12-21 03:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 1 2019-12-21 07:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 2 2019-12-21 11:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 3 2019-12-21 15:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
# 4 2019-12-21 19:00:00  A002  R051  02-00-00   59 ST  NQR456W      BMT
#
#          DATE      TIME        DESC  ENTRIES  \
# 0  12/21/2019  03:00:00     REGULAR  7318040
# 1  12/21/2019  07:00:00     REGULAR  7318049
# 2  12/21/2019  11:00:00  RECOVR AUD  7318101
# 3  12/21/2019  15:00:00     REGULAR  7318263
# 4  12/21/2019  19:00:00     REGULAR  7318559
#
#    EXITS
# 0                                            2480587
# 1                                            2480598
# 2                                            2480680
# 3                                            2480763
# 4                                            2480823

# %% [markdown]
# An important note about this dataFrame:
# - The ``ENTRIES`` and ``EXITS`` columns are **cumulative**. In order for us to analyze AMPM traffic, we need to convert these columns from cumulative to hourly (in 4 hour increments, since that's how the data is formatted).
#     - before we can do that, we need to remove some rows that were added as a result of an audit (can think of these as corrections). There is a relatively small amount of them (about 7k of 1.63M rows using the default weeks.)

# %%
mask = df_turnstiles.DESC == 'RECOVR AUD'
df_turnstiles[mask].shape, df_turnstiles.shape
# Out:
# ((7102, 12), (1649098, 12))

# %% [markdown]
# Now let's get rid of the rows where ``turnstiles_df.DESC == 'RECOVR AUD'``. To do this, we will sort the rows so that the correct entry will come before the 'RECOVR AUD' entry. Then, we can apply the ``drop_duplicates`` dataFrame method to get rid of those rows.
#
# Then, since we've removed all rows where ``DESC`` is not ``'REGULAR'``, we can drop the column entirely.

# %%
df_turnstiles.sort_values(
            ["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"],
            inplace=True,
            ascending=False)

# keeps top row, deletes others
df_turnstiles.drop_duplicates(
    subset=["C/A", "UNIT", "SCP", "STATION", "DATE_TIME"], inplace=True
)

# remove DESC column
df_turnstiles = df_turnstiles.drop(["DESC"], axis=1, errors="ignore")

df_turnstiles.head(5)
# Out:
#                  DATE_TIME    C/A  UNIT       SCP        STATION LINENAME  \
# 206706 2019-12-27 20:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206705 2019-12-27 16:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206704 2019-12-27 12:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206703 2019-12-27 08:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206702 2019-12-27 04:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#
#        DIVISION        DATE      TIME  ENTRIES  \
# 206706      RIT  12/27/2019  20:00:00     5554
# 206705      RIT  12/27/2019  16:00:00     5554
# 206704      RIT  12/27/2019  12:00:00     5554
# 206703      RIT  12/27/2019  08:00:00     5554
# 206702      RIT  12/27/2019  04:00:00     5554
#
#         EXITS
# 206706                                                420
# 206705                                                420
# 206704                                                420
# 206703                                                420
# 206702                                                420

# %% [markdown]
# Great, now we can see that there is no more DESC column.
#
# As you can see in the output of the below cell, the ``EXITS`` column has a lot of spaces after it. Let's fix that so we can easily select this column in the future.

# %%
df_turnstiles.columns
# Out:
# Index(['DATE_TIME', 'C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION',
#        'DATE', 'TIME', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
df_turnstiles.rename(columns={"EXITS                                                               ": "EXITS"},
            inplace=True)

# %% [markdown]
# Now, let's add the AMPM column.
#
# **NOTE**: This cell takes a while, so avoid re-running if possible.

# %%
df_turnstiles["AMPM"] = (pd.DatetimeIndex(df_turnstiles["TIME"]).strftime("%r").str[-2:])
df_turnstiles.head(3)
# Out:
#                  DATE_TIME    C/A  UNIT       SCP        STATION LINENAME  \
# 206706 2019-12-27 20:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206705 2019-12-27 16:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206704 2019-12-27 12:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#
#        DIVISION        DATE      TIME  ENTRIES  EXITS AMPM
# 206706      RIT  12/27/2019  20:00:00     5554    420   PM
# 206705      RIT  12/27/2019  16:00:00     5554    420   PM
# 206704      RIT  12/27/2019  12:00:00     5554    420   PM

# %% [markdown]
# And day name.

# %%
df_turnstiles["DAY_NAME"] = pd.to_datetime(df_turnstiles["DATE"]).dt.day_name()
df_turnstiles.head(3)
# Out:
#                  DATE_TIME    C/A  UNIT       SCP        STATION LINENAME  \
# 206706 2019-12-27 20:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206705 2019-12-27 16:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206704 2019-12-27 12:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#
#        DIVISION        DATE      TIME  ENTRIES  EXITS AMPM DAY_NAME
# 206706      RIT  12/27/2019  20:00:00     5554    420   PM   Friday
# 206705      RIT  12/27/2019  16:00:00     5554    420   PM   Friday
# 206704      RIT  12/27/2019  12:00:00     5554    420   PM   Friday

# %% [markdown]
# We eventually want to add the adjusted gross income of each station. To get that, we need zipcode. And to get zipcode, we will to take the lat/lon data provided in MTA's station data and pass it to Google's **geocode** API.

# %%
# Read in mta station's zipcode and income data into ``df_turnstiles``
mta_station_info = pd.read_csv("http://web.mta.info/developers/data/nyct/subway/Stations.csv")
mta_station_info.rename(columns={'Stop Name': 'STATION', 'GTFS Latitude': 'Lat', 'GTFS Longitude': 'Lon'}, inplace=True)

mta_station_info.head()
# Out:
#    Station ID  Complex ID GTFS Stop ID Division     Line  \
# 0           1           1          R01      BMT  Astoria
# 1           2           2          R03      BMT  Astoria
# 2           3           3          R04      BMT  Astoria
# 3           4           4          R05      BMT  Astoria
# 4           5           5          R06      BMT  Astoria
#
#                 STATION Borough Daytime Routes Structure        Lat  \
# 0  Astoria-Ditmars Blvd       Q            N W  Elevated  40.775036
# 1          Astoria Blvd       Q            N W  Elevated  40.770258
# 2                 30 Av       Q            N W  Elevated  40.766779
# 3              Broadway       Q            N W  Elevated  40.761820
# 4                 36 Av       Q            N W  Elevated  40.756804
#
#          Lon   North Direction Label South Direction Label  ADA ADA Notes
# 0 -73.912034                     NaN             Manhattan    0       NaN
# 1 -73.917843            Ditmars Blvd             Manhattan    1       NaN
# 2 -73.921479  Astoria - Ditmars Blvd             Manhattan    0       NaN
# 3 -73.925508  Astoria - Ditmars Blvd             Manhattan    0       NaN
# 4 -73.929575  Astoria - Ditmars Blvd             Manhattan    0       NaN

# %% [markdown]
# Nice! Now we have the station data...but still no zipcode. Let's get the station names and let Google do the rest.
#
#
# **NOTE 1**: This part requires a key for Google's geocode API. The below key will be deactivated before it's made public.
#
# **NOTE 2**: This will take some time. Go get yourself a drink!

# %%
import googlemaps

# you will need to get your own API Key, this API key will not work for you.
# get your own at: https://developers.google.com/maps/documentation/geocoding/start
gmaps = googlemaps.Client(key='AIzaSyAn-enZAKGfjRe3WguahiEy1K4QwB9xO2s') 

station_zips = {}
mta_station_names = list(mta_station_info.STATION.unique())

for station in mta_station_names:
    # we want to query geocode with the most accurate address possible
    address = station + ' Station New York City, NY'
    geocode_result = gmaps.geocode(address)
    try:
        # due to the funky json returned from geocode we need to access zip code like this
        zipcode = geocode_result[0]['address_components'][6]['long_name']
        if len(zipcode) == 5:
            station_zips[station.upper()] = str(zipcode) 
    except:
        continue

# %% [markdown]
# Let's take a look at what we just generated.

# %%
station_zips
# Out:
# {'ASTORIA-DITMARS BLVD': '11105',
#  '30 AV': '11102',
#  '36 AV': '11106',
#  '39 AV-DUTCH KILLS': '11101',
#  'LEXINGTON AV/59 ST': '10065',
#  '5 AV/59 ST': '10019',
#  '57 ST-7 AV': '10106',
#  '49 ST': '10019',
#  'TIMES SQ-42 ST': '10018',
#  '34 ST-HERALD SQ': '10001',
#  '28 ST': '10001',
#  '23 ST': '10011',
#  '14 ST-UNION SQ': '10003',
#  '8 ST-NYU': '10003',
#  'PRINCE ST': '10012',
#  'CANAL ST': '10013',
#  'CITY HALL': '10013',
#  'CORTLANDT ST': '10007',
#  'RECTOR ST': '10006',
#  'COURT ST': '11201',
#  'JAY ST-METROTECH': '11201',
#  'DEKALB AV': '11217',
#  'UNION ST': '11215',
#  '4 AV-9 ST': '11215',
#  'PROSPECT AV': '11215',
#  '36 ST': '10012',
#  '53 ST': '10022',
#  'BAY RIDGE AV': '11220',
#  'BAY RIDGE-95 ST': '11209',
#  '7 AV': '10019',
#  'PARKSIDE AV': '11226',
#  'CHURCH AV': '11226',
#  'BEVERLEY RD': '11226',
#  'CORTELYOU RD': '11226',
#  'NEWKIRK PLAZA': '11226',
#  'AVENUE H': '11230',
#  'AVENUE J': '11230',
#  'AVENUE M': '11230',
#  'KINGS HWY': '11229',
#  'AVENUE U': '11223',
#  'NECK RD': '11229',
#  'SHEEPSHEAD BAY': '11235',
#  'BRIGHTON BEACH': '11235',
#  'OCEAN PKWY': '11235',
#  'W 8 ST-NY AQUARIUM': '11224',
#  'CONEY ISLAND-STILLWELL AV': '11224',
#  '9 AV': '11219',
#  '50 ST': '10019',
#  '55 ST': '11219',
#  '62 ST': '11219',
#  '71 ST': '11228',
#  '79 ST': '10024',
#  '18 AV': '11230',
#  '20 AV': '11204',
#  'BAY PKWY': '11214',
#  '25 AV': '11214',
#  'BAY 50 ST': '11214',
#  'NEW UTRECHT AV': '11219',
#  '121 ST': '11418',
#  '111 ST': '11418',
#  '104 ST': '11418',
#  'WOODHAVEN BLVD': '11373',
#  '75 ST-ELDERTS LN': '11421',
#  'CYPRESS HILLS': '11208',
#  'CRESCENT ST': '11106',
#  'NORWOOD AV': '11208',
#  'CLEVELAND ST': '11208',
#  'VAN SICLEN AV': '11207',
#  'ALABAMA AV': '11207',
#  'CHAUNCEY ST': '11207',
#  'HALSEY ST': '11237',
#  'GATES AV': '11221',
#  'KOSCIUSZKO ST': '11221',
#  'LORIMER ST': '11211',
#  'HEWES ST': '11211',
#  'MARCY AV': '11211',
#  'DELANCEY ST-ESSEX ST': '10002',
#  'BOWERY': '10002',
#  'CHAMBERS ST': '10007',
#  'BROAD ST': '10005',
#  'MIDDLE VILLAGE-METROPOLITAN AV': '11381',
#  'FOREST AV': '11385',
#  'SENECA AV': '11385',
#  'MYRTLE-WYCKOFF AVS': '11237',
#  'KNICKERBOCKER AV': '11237',
#  'CENTRAL AV': '11221',
#  '6 AV': '10011',
#  '14 ST-UNION SQ.': '10003',
#  '3 AV': '10003',
#  'BEDFORD AV': '11211',
#  'GRAHAM AV': '11211',
#  'GRAND ST': '11211',
#  'MORGAN AV': '11237',
#  'WILSON AV': '11207',
#  'BUSHWICK AV-ABERDEEN ST': '11207',
#  'ATLANTIC AV': '11207',
#  'SUTTER AV': '11207',
#  'LIVONIA AV': '11212',
#  'NEW LOTS AV': '11207',
#  'EAST 105 ST': '10029',
#  'CANARSIE-ROCKAWAY PKWY': '11236',
#  'FRANKLIN AV': '10013',
#  'PARK PL': '10007',
#  'BOTANIC GARDEN': '10458',
#  'INWOOD-207 ST': '10034',
#  'DYCKMAN ST': '10034',
#  '181 ST': '10033',
#  '168 ST': '10032',
#  '163 ST-AMSTERDAM AV': '10032',
#  '155 ST': '10039',
#  '145 ST': '10031',
#  '135 ST': '10030',
#  '116 ST': '10035',
#  'CATHEDRAL PKWY (110 ST)': '10026',
#  '103 ST': '10025',
#  '96 ST': '10029',
#  '81 ST-MUSEUM OF NATURAL HISTORY': '10024',
#  '72 ST': '10023',
#  '34 ST-PENN STATION': '10001',
#  '14 ST': '10011',
#  'SPRING ST': '10012',
#  'WORLD TRADE CENTER': '10007',
#  'HOYT-SCHERMERHORN STS': '11201',
#  'LAFAYETTE AV': '11217',
#  'CLINTON-WASHINGTON AVS': '11238',
#  'NOSTRAND AV': '11225',
#  'KINGSTON-THROOP AVS': '11213',
#  'UTICA AV': '11213',
#  'RALPH AV': '11233',
#  'ROCKAWAY AV': '11224',
#  'LIBERTY AV': '11207',
#  'SHEPHERD AV': '11208',
#  'EUCLID AV': '11208',
#  'GRANT AV': '11208',
#  '80 ST': '11417',
#  '88 ST': '11417',
#  'ROCKAWAY BLVD': '11417',
#  'OZONE PARK-LEFFERTS BLVD': '11419',
#  'AQUEDUCT RACETRACK': '11417',
#  'BROAD CHANNEL': '11693',
#  'BEACH 90 ST': '11693',
#  'BEACH 98 ST': '11694',
#  'BEACH 105 ST': '11694',
#  'ROCKAWAY PARK-BEACH 116 ST': '11694',
#  'BEACH 67 ST': '11692',
#  'BEACH 60 ST': '11692',
#  'BEACH 44 ST': '11691',
#  'BEACH 36 ST': '11691',
#  'FAR ROCKAWAY-MOTT AV': '11691',
#  'NORWOOD-205 ST': '10467',
#  'BEDFORD PARK BLVD': '10468',
#  'KINGSBRIDGE RD': '10468',
#  '182-183 STS': '10453',
#  'TREMONT AV': '10460',
#  '174-175 STS': '10453',
#  '167 ST': '10452',
#  '21 ST-QUEENSBRIDGE': '11101',
#  'ROOSEVELT ISLAND': '10044',
#  'LEXINGTON AV/63 ST': '10065',
#  '57 ST': '10019',
#  '47-50 STS-ROCKEFELLER CTR': '10020',
#  '42 ST-BRYANT PK': '10018',
#  '2 AV': '10003',
#  'EAST BROADWAY': '10002',
#  'BERGEN ST': '11201',
#  '15 ST-PROSPECT PARK': '11215',
#  'DITMAS AV': '11218',
#  'AVENUE I': '11230',
#  'AVENUE N': '11230',
#  'AVENUE P': '11223',
#  'AVENUE X': '11223',
#  '169 ST': '11432',
#  'PARSONS BLVD': '11432',
#  '75 AV': '11375',
#  'FOREST HILLS-71 AV': '11375',
#  '67 AV': '11375',
#  '63 DR-REGO PARK': '11374',
#  'GRAND AV-NEWTOWN': '11373',
#  'ELMHURST AV': '11372',
#  '65 ST': '11377',
#  'NORTHERN BLVD': '11377',
#  '46 ST': '11103',
#  'QUEENS PLAZA': '11101',
#  'COURT SQ-23 ST': '11101',
#  'LEXINGTON AV/53 ST': '10022',
#  '5 AV/53 ST': '10022',
#  'SUTPHIN BLVD-ARCHER AV-JFK AIRPORT': '11435',
#  'JAMAICA-VAN WYCK': '11418',
#  'COURT SQ': '11101',
#  '21 ST': '11101',
#  'GREENPOINT AV': '11222',
#  'NASSAU AV': '11222',
#  'METROPOLITAN AV': '11381',
#  'MYRTLE-WILLOUGHBY AVS': '11206',
#  'BEDFORD-NOSTRAND AVS': '11205',
#  'CLASSON AV': '11238',
#  'VAN CORTLANDT PARK-242 ST': '10471',
#  '238 ST': '10463',
#  '231 ST': '10463',
#  'MARBLE HILL-225 ST': '10034',
#  '215 ST': '10034',
#  '207 ST': '10034',
#  '168 ST-WASHINGTON HTS': '10032',
#  '157 ST': '10032',
#  '137 ST-CITY COLLEGE': '10031',
#  '116 ST-COLUMBIA UNIVERSITY': '10027',
#  '66 ST-LINCOLN CENTER': '10023',
#  '18 ST': '10011',
#  'CHRISTOPHER ST-SHERIDAN SQ': '10014',
#  'FRANKLIN ST': '10013',
#  'WTC CORTLANDT': '10006',
#  'SOUTH FERRY': '10004',
#  'PARK PLACE': '10007',
#  'WALL ST': '10006',
#  'CLARK ST': '11201',
#  'HOYT ST': '11201',
#  'NEVINS ST': '11217',
#  'GRAND ARMY PLAZA': '11238',
#  'FRANKLIN AVENUE-MEDGAR EVERS COLLEGE': '11225',
#  'KINGSTON AV': '11213',
#  'CROWN HTS-UTICA AV': '11213',
#  'SUTTER AV-RUTLAND RD': '11212',
#  'SARATOGA AV': '11212',
#  'JUNIUS ST': '11212',
#  'PENNSYLVANIA AV': '11207',
#  'PRESIDENT STREET-MEDGAR EVERS COLLEGE': '11225',
#  'STERLING ST': '11225',
#  'WINTHROP ST': '11225',
#  'BEVERLY RD': '11226',
#  'PELHAM BAY PARK': '10461',
#  'BUHRE AV': '10461',
#  'MIDDLETOWN RD': '10461',
#  'WESTCHESTER SQ-E TREMONT AV': '10461',
#  'ZEREGA AV': '10461',
#  'CASTLE HILL AV': '10462',
#  'PARKCHESTER': '10472',
#  'ST LAWRENCE AV': '10472',
#  'MORRISON AV-SOUNDVIEW': '10472',
#  'ELDER AV': '10472',
#  'WHITLOCK AV': '10459',
#  'HUNTS POINT AV': '10474',
#  'LONGWOOD AV': '10455',
#  "E 143 ST-ST MARY'S ST": '10454',
#  'CYPRESS AV': '10454',
#  'BROOK AV': '10454',
#  '3 AV-138 ST': '10454',
#  'MOSHOLU PKWY': '10467',
#  'BEDFORD PARK BLVD-LEHMAN COLLEGE': '10468',
#  '183 ST': '10453',
#  'BURNSIDE AV': '10453',
#  '176 ST': '10453',
#  'MT EDEN AV': '10452',
#  '149 ST-GRAND CONCOURSE': '10451',
#  '138 ST-GRAND CONCOURSE': '10451',
#  '110 ST': '10029',
#  '68 ST-HUNTER COLLEGE': '10021',
#  'GRAND CENTRAL-42 ST': '10017',
#  '33 ST': '10001',
#  'ASTOR PL': '10003',
#  'BLEECKER ST': '10012',
#  'BROOKLYN BRIDGE-CITY HALL': '10013',
#  'BOWLING GREEN': '10004',
#  'WAKEFIELD-241 ST': '10470',
#  '233 ST': '10466',
#  '225 ST': '10466',
#  '219 ST': '10467',
#  'GUN HILL RD': '10467',
#  'BURKE AV': '10467',
#  'ALLERTON AV': '10467',
#  'BRONX PARK EAST': '10462',
#  'E 180 ST': '10460',
#  'WEST FARMS SQ-E TREMONT AV': '10460',
#  '174 ST': '10460',
#  'FREEMAN ST': '10459',
#  'SIMPSON ST': '10459',
#  'INTERVALE AV': '10459',
#  'JACKSON AV': '10455',
#  '3 AV-149 ST': '10455',
#  'HARLEM-148 ST': '10039',
#  'CENTRAL PARK NORTH (110 ST)': '10026',
#  'EASTCHESTER-DYRE AV': '10466',
#  'BAYCHESTER AV': '10469',
#  'MORRIS PARK': '10462',
#  'FLUSHING-MAIN ST': '11354',
#  'METS-WILLETS POINT': '11368',
#  'JUNCTION BLVD': '11368',
#  '90 ST-ELMHURST AV': '11372',
#  '69 ST': '11377',
#  'WOODSIDE-61 ST': '11377',
#  '52 ST': '11377',
#  '46 ST-BLISS ST': '11104',
#  '40 ST-LOWERY ST': '11104',
#  '33 ST-RAWSON ST': '11101',
#  'QUEENSBORO PLAZA': '11101',
#  'HUNTERS POINT AV': '11101',
#  'VERNON BLVD-JACKSON AV': '11101',
#  'TOMPKINSVILLE': '10304',
#  'STAPLETON': '10304',
#  'CLIFTON': '10304',
#  'GRASMERE': '10305',
#  'OLD TOWN': '10305',
#  'JEFFERSON AV': '10306',
#  'GRANT CITY': '10306',
#  'NEW DORP': '10306',
#  'OAKWOOD HEIGHTS': '10306',
#  'BAY TERRACE': '10306',
#  'GREAT KILLS': '10308',
#  'ANNADALE': '10312',
#  "PRINCE'S BAY": '10309',
#  'PLEASANT PLAINS': '10309',
#  'RICHMOND VALLEY': '10309',
#  'ARTHUR KILL': '10307'}

# %% [markdown]
# ``station_zips`` now contains the zip codes for each station. Some are missing - that's because some zip codes in New York are so small that Google doesn't have the data for them.
#
# Now let's add that to our dataFrames!

# %%
mta_station_info['ZIPCODE'] = mta_station_info['STATION'].str.upper().map(station_zips)
df_turnstiles['ZIPCODE'] = df_turnstiles['STATION'].map(station_zips)
df_turnstiles.sample(10)
# Out:
#                  DATE_TIME    C/A  UNIT       SCP          STATION  \
# 45085  2019-12-06 12:00:00   N009  R174  01-00-01           181 ST
# 128546 2019-11-25 04:00:00   R101  R001  02-06-04      SOUTH FERRY
# 54135  2019-12-22 19:00:00  N063A  R011  00-00-08  42 ST-PORT AUTH
# 74928  2019-11-28 16:00:00   N213  R154  00-00-00       TREMONT AV
# 182661 2019-11-10 23:00:00   R508  R346  00-00-02         COURT SQ
# 146976 2019-11-15 19:00:00   R186  R036  00-00-00       DYCKMAN ST
# 57977  2019-11-08 08:00:00   N078  R175  01-00-05            14 ST
# 168809 2019-11-10 07:00:00   R288  R275  00-00-03           183 ST
# 95629  2019-12-14 08:00:00  N414A  R316  01-06-01      FLUSHING AV
# 71463  2019-11-23 20:00:00   N187  R419  00-00-02  ROCKAWAY PARK B
#
#             LINENAME DIVISION        DATE      TIME     ENTRIES      EXITS  \
# 45085              A      IND  12/06/2019  12:00:00     8238822    6674204
# 128546           1RW      IRT  11/25/2019  04:00:00         196          0
# 54135   ACENQRS1237W      IND  12/22/2019  19:00:00   413095444  302493476
# 74928             BD      IND  11/28/2019  16:00:00     3313534    2431493
# 182661             7      IRT  11/10/2019  23:00:00     1830146     925005
# 146976             1      IRT  11/15/2019  19:00:00     1968583    2440587
# 57977           ACEL      IND  11/08/2019  08:00:00     8158825    4442758
# 168809             4      IRT  11/10/2019  07:00:00  1594635109  419746743
# 95629              G      IND  12/14/2019  08:00:00     2335742    2947985
# 71463             AS      IND  11/23/2019  20:00:00     3625062   10281978
#
#        AMPM  DAY_NAME ZIPCODE
# 45085    PM    Friday   10033
# 128546   AM    Monday   10004
# 54135    PM    Sunday     NaN
# 74928    PM  Thursday   10460
# 182661   PM    Sunday   11101
# 146976   PM    Friday   10034
# 57977    AM    Friday   10011
# 168809   AM    Sunday   10453
# 95629    AM  Saturday     NaN
# 71463    PM  Saturday     NaN

# %% [markdown]
# Now, we'll retrieve income information for the entire United States by zipcode (from the IRS)

# %%
us_zips_agi = pd.read_csv("https://www.irs.gov/pub/irs-soi/18zpallagi.csv")
us_zips_agi.rename(columns={'A00100':'adj_gross_inc'}, inplace=True) # in 18zpallagi.csv, A00100 stands for AGI
us_zips_agi = us_zips_agi[['zipcode','adj_gross_inc']].groupby('zipcode').agg(sum)

# %% [markdown]
# We can sort this zipcode/agi data into NYC zipcodes by joining the data with a list of nyc_zipcodes (ny_zips.csv)

# %%
nyc_zips = pd.read_csv("data/ny_zips.csv")
nyc_zips.dropna(axis=1, how='all', inplace=True)
nyc_agi_by_zip = nyc_zips.join(us_zips_agi, how='inner', on='zipcode')

# must capitalize col name & change from dtype 'object' to 'str' in order to merge into df_turnstiles
nyc_agi_by_zip.columns = nyc_agi_by_zip.columns.str.upper()
nyc_agi_by_zip['ZIPCODE'] = nyc_agi_by_zip.ZIPCODE.astype(str)

nyc_agi_by_zip.head(10)
# Out:
#   ZIPCODE       AREA  ADJ_GROSS_INC
# 0   10001  Manhattan      2906435.0
# 1   10002  Manhattan      2718913.0
# 2   10003  Manhattan      8191737.0
# 3   10004  Manhattan       944925.0
# 4   10005  Manhattan      2603668.0
# 5   10006  Manhattan       577145.0
# 6   10007  Manhattan      2910802.0
# 7   10009  Manhattan      2948597.0
# 8   10010  Manhattan      4542337.0
# 9   10011  Manhattan      9331779.0

# %%
nyc_agi_by_zip[['ZIPCODE', 'ADJ_GROSS_INC']].set_index('ZIPCODE').to_dict()['ADJ_GROSS_INC']
# Out:
# {'10001': 2906435.0,
#  '10002': 2718913.0,
#  '10003': 8191737.0,
#  '10004': 944925.0,
#  '10005': 2603668.0,
#  '10006': 577145.0,
#  '10007': 2910802.0,
#  '10009': 2948597.0,
#  '10010': 4542337.0,
#  '10011': 9331779.0,
#  '10012': 3646355.0,
#  '10013': 7947938.0,
#  '10014': 6795181.0,
#  '10016': 8000771.0,
#  '10017': 4417331.0,
#  '10018': 3964454.0,
#  '10019': 8005583.0,
#  '10021': 12798847.0,
#  '10022': 14226340.0,
#  '10023': 12391069.0,
#  '10024': 13806195.0,
#  '10025': 8028810.0,
#  '10026': 1440633.0,
#  '10027': 1972417.0,
#  '10028': 10128983.0,
#  '10029': 2022052.0,
#  '10030': 645026.0,
#  '10031': 1401061.0,
#  '10032': 1270384.0,
#  '10033': 1360083.0,
#  '10034': 1019289.0,
#  '10035': 833400.0,
#  '10036': 4568142.0,
#  '10037': 570270.0,
#  '10038': 1953888.0,
#  '10039': 586050.0,
#  '10040': 1037660.0,
#  '10044': 472585.0,
#  '10069': 1777529.0,
#  '10128': 12570244.0,
#  '10162': 203692.0,
#  '10280': 1047685.0,
#  '10282': 1442366.0,
#  '10301': 1369609.0,
#  '10302': 458236.0,
#  '10303': 594095.0,
#  '10304': 1515252.0,
#  '10305': 1278252.0,
#  '10306': 2132001.0,
#  '10307': 657079.0,
#  '10308': 1124965.0,
#  '10309': 1420600.0,
#  '10310': 776063.0,
#  '10312': 2582965.0,
#  '10314': 3085380.0,
#  '10451': 857426.0,
#  '10452': 1129896.0,
#  '10453': 1118282.0,
#  '10454': 488519.0,
#  '10455': 574656.0,
#  '10456': 1209535.0,
#  '10457': 997507.0,
#  '10458': 1116373.0,
#  '10459': 678052.0,
#  '10460': 826025.0,
#  '10461': 1346454.0,
#  '10462': 1795269.0,
#  '10463': 2432458.0,
#  '10464': 212670.0,
#  '10465': 1287456.0,
#  '10466': 1388485.0,
#  '10467': 1714750.0,
#  '10468': 1203575.0,
#  '10469': 1593018.0,
#  '10470': 435453.0,
#  '10471': 1390724.0,
#  '10472': 971500.0,
#  '10473': 1203457.0,
#  '10474': 155708.0,
#  '10475': 1153512.0,
#  '11004': 497011.0,
#  '11101': 2273198.0,
#  '11102': 1225616.0,
#  '11103': 1269650.0,
#  '11104': 1013072.0,
#  '11105': 1347282.0,
#  '11106': 1391829.0,
#  '11109': 700625.0,
#  '11201': 7714299.0,
#  '11203': 1679309.0,
#  '11204': 1935543.0,
#  '11205': 1529774.0,
#  '11206': 1771285.0,
#  '11207': 1650855.0,
#  '11208': 1586724.0,
#  '11209': 2811643.0,
#  '11210': 2348707.0,
#  '11211': 2684922.0,
#  '11212': 1344174.0,
#  '11213': 1378248.0,
#  '11214': 1930773.0,
#  '11215': 5454584.0,
#  '11216': 1830296.0,
#  '11217': 3143030.0,
#  '11218': 2212234.0,
#  '11219': 1635884.0,
#  '11220': 1748844.0,
#  '11221': 1958838.0,
#  '11222': 2098579.0,
#  '11223': 2556150.0,
#  '11224': 910704.0,
#  '11225': 1755176.0,
#  '11226': 2466184.0,
#  '11228': 1336182.0,
#  '11229': 2423575.0,
#  '11230': 2773769.0,
#  '11231': 2885921.0,
#  '11232': 618142.0,
#  '11233': 1471332.0,
#  '11234': 3023834.0,
#  '11235': 2567055.0,
#  '11236': 2301827.0,
#  '11237': 1030147.0,
#  '11238': 3353662.0,
#  '11239': 322447.0,
#  '11354': 1299395.0,
#  '11355': 1610782.0,
#  '11356': 589237.0,
#  '11357': 1898492.0,
#  '11358': 1220462.0,
#  '11360': 1004624.0,
#  '11361': 1014165.0,
#  '11362': 774948.0,
#  '11363': 458581.0,
#  '11364': 1300224.0,
#  '11365': 1279603.0,
#  '11366': 490003.0,
#  '11367': 1312965.0,
#  '11368': 1609584.0,
#  '11369': 732524.0,
#  '11370': 687350.0,
#  '11372': 1791324.0,
#  '11373': 1951391.0,
#  '11374': 1606102.0,
#  '11375': 3714463.0,
#  '11377': 2133352.0,
#  '11378': 1034753.0,
#  '11379': 1335108.0,
#  '11385': 2525905.0,
#  '11411': 604233.0,
#  '11412': 945365.0,
#  '11413': 1147871.0,
#  '11414': 1018439.0,
#  '11415': 706738.0,
#  '11416': 490762.0,
#  '11417': 724600.0,
#  '11418': 840143.0,
#  '11419': 924466.0,
#  '11420': 1069765.0,
#  '11421': 921337.0,
#  '11422': 876114.0,
#  '11423': 812347.0,
#  '11426': 626861.0,
#  '11427': 754242.0,
#  '11428': 515246.0,
#  '11429': 633574.0,
#  '11432': 1430777.0,
#  '11433': 673077.0,
#  '11434': 1548972.0,
#  '11435': 1225636.0,
#  '11436': 435964.0,
#  '11691': 1033194.0,
#  '11692': 393888.0,
#  '11693': 319792.0,
#  '11694': 850523.0,
#  '11697': 253659.0}

# %% [markdown]
# Great! Now we can add AGI to our turnstiles DataFrames. Let's do that now.

# %%
# convert ZIPCODE and ADJ_GROSS_INC cols to dict{zipcode: AGI}
zipcode_agis = nyc_agi_by_zip[['ZIPCODE', 'ADJ_GROSS_INC']].set_index('ZIPCODE').to_dict()['ADJ_GROSS_INC']

# use the dictionary to add ZIPCODE_AGI column to df_turnstiles
df_turnstiles['ZIPCODE_AGI'] = df_turnstiles['ZIPCODE'].map(zipcode_agis)
df_turnstiles.sample(10)
# Out:
#                  DATE_TIME    C/A  UNIT       SCP          STATION   LINENAME  \
# 153438 2019-11-08 16:00:00  R205A  R014  04-03-01        FULTON ST   2345ACJZ
# 121678 2019-12-01 07:21:30  PTH11  R545  00-04-03      14TH STREET          1
# 15151  2019-11-21 07:00:00   B018  R184  00-00-00     CORTELYOU RD         BQ
# 187178 2019-11-14 11:00:00   R526  R096  00-00-01  82 ST-JACKSON H          7
# 132325 2019-11-22 07:00:00   R116  R030  00-03-00      CHAMBERS ST        123
# 73513  2019-11-19 15:22:00   N205  R195  02-00-02  161/YANKEE STAD        BD4
# 107972 2019-12-18 03:00:00   N546  R204  00-00-01        CHURCH AV         FG
# 80288  2019-12-12 12:00:00  N309A  R140  00-05-03     QUEENS PLAZA        EMR
# 196253 2019-12-01 11:00:00   R610  R057  00-03-04   ATL AV-BARCLAY  2345BDNQR
# 12330  2019-11-19 14:00:00   A077  R028  03-03-00        FULTON ST   ACJZ2345
#
#        DIVISION        DATE      TIME  ENTRIES    EXITS AMPM   DAY_NAME  \
# 153438      IRT  11/08/2019  16:00:00  2603919  1566113   PM     Friday
# 121678      PTH  12/01/2019  07:21:30     5176   173579   AM     Sunday
# 15151       BMT  11/21/2019  07:00:00   868005   373694   AM   Thursday
# 187178      IRT  11/14/2019  11:00:00   398528   742131   AM   Thursday
# 132325      IRT  11/22/2019  07:00:00  3928030  4830690   AM     Friday
# 73513       IND  11/19/2019  15:22:00  4063214  1490033   PM    Tuesday
# 107972      IND  12/18/2019  03:00:00  5051780  8555278   AM  Wednesday
# 80288       IND  12/12/2019  12:00:00        0      537   PM   Thursday
# 196253      IRT  12/01/2019  11:00:00  1356751   189025   AM     Sunday
# 12330       BMT  11/19/2019  14:00:00  4692103  2771684   PM    Tuesday
#
#        ZIPCODE  ZIPCODE_AGI
# 153438     NaN          NaN
# 121678     NaN          NaN
# 15151    11226    2466184.0
# 187178     NaN          NaN
# 132325   10007    2910802.0
# 73513      NaN          NaN
# 107972   11226    2466184.0
# 80288    11101    2273198.0
# 196253     NaN          NaN
# 12330      NaN          NaN

# %% [markdown]
# Cool, that worked! Now we have both zipcode and zipcode_agi in our dataFrame.
#
# Now it's time to convert ENTRIES and EXITS columns from cumulative to it's change from previous value.
#
# We do this by shifting the previous values forward, then subtracting the previous values from the current ones. For this to work, the data must be sorted by station & datetime (it already is).

# %%
# group data by AMPM, taking the maximum entries/exits for each date 
ampm_station_group = df_turnstiles.groupby(["C/A", "UNIT", "SCP", "STATION", "ZIPCODE", "ZIPCODE_AGI", "DATE", "AMPM", "DAY_NAME"],
    as_index=False)

df_ampm = ampm_station_group.ENTRIES.max()
ampm_station_exits = ampm_station_group.EXITS.max()
df_ampm["EXITS"] = ampm_station_exits["EXITS"]

# create prev_date and prev_entries cols by shifting these columns forward one day
# if shifting date and entries, don't group by date
df_ampm[["PREV_DATE", "PREV_ENTRIES", "PREV_EXITS"]] = df_ampm.groupby(
    ["C/A", "UNIT", "SCP", "STATION", "ZIPCODE", "ZIPCODE_AGI", "AMPM"]
)[["DATE", "ENTRIES", "EXITS"]].apply(lambda grp: grp.shift(1))

# Drop the rows for the earliest date in the df, which are now NaNs for prev_date and prev_entries cols
df_ampm.dropna(subset=["PREV_DATE"], axis=0, inplace=True)

df_ampm.head()
# Out:
#     C/A  UNIT       SCP     STATION ZIPCODE ZIPCODE_AGI        DATE AMPM  \
# 2  A006  R079  00-00-00  5 AV/59 ST   10019       10019  11/03/2019   AM
# 3  A006  R079  00-00-00  5 AV/59 ST   10019       10019  11/03/2019   PM
# 4  A006  R079  00-00-00  5 AV/59 ST   10019       10019  11/04/2019   AM
# 5  A006  R079  00-00-00  5 AV/59 ST   10019       10019  11/04/2019   PM
# 6  A006  R079  00-00-00  5 AV/59 ST   10019       10019  11/05/2019   AM
#
#   DAY_NAME  ENTRIES    EXITS   PREV_DATE  PREV_ENTRIES  PREV_EXITS
# 2   Sunday  4099092  7058848  11/02/2019     4097957.0   7057072.0
# 3   Sunday  4099979  7060287  11/02/2019     4098923.0   7058586.0
# 4   Monday  4100128  7061222  11/03/2019     4099092.0   7058848.0
# 5   Monday  4101641  7063433  11/03/2019     4099979.0   7060287.0
# 6  Tuesday  4101898  7064433  11/04/2019     4100128.0   7061222.0

# %% [markdown]
# Alright, as we can see above, we now have ``PREV_ENTRIES`` and ``PREV_EXITS`` columns, and they seem mostly correct. However, there is a lot of data, and we noticed that sometimes ``PREV_ENTRIES`` > ``ENTRIES``. This shouldn't be...in fact, we determined that some stations were counting in reverse! In other cases, the variance to the previous count was hundreds of thousands, sometimes millions. We decided to cap these at 200,000 to maintain our data's integrity as best as possible.
#
# The below functions takes care of this for us for both ENTRIES and EXITS.

# %%
def add_counts(row, max_counter, column_name):
    """
    Takes:
        - max_counter is the maximum difference between entries/exits & their prev. row values that
    we will allow.
    column_name (string): which column to count
    """

    counter = row[column_name] - row[f"PREV_{column_name}"]
    if counter < 0:
        # Maybe counter is reversed?
        counter = -counter

    if counter > max_counter:
        # Maybe counter was reset to 0?
        # take the lower value as the counter for this row
        counter = min(row[column_name], row[f"PREV_{column_name}"])

    if counter > max_counter:
        # Check it again to make sure we're not still giving a counter that's too big
        return 0

    return counter

# %% [markdown]
# Alright, now let's apply this function to our dataFrames.

# %%
# we will use a 200k counter - anything more seems incorrect.
df_ampm["TMP_ENTRIES"] = df_ampm.apply(
    add_counts, axis=1, max_counter=200000, column_name='ENTRIES')

df_ampm["TMP_EXITS"] = df_ampm.apply(
    add_counts, axis=1, max_counter=200000, column_name='EXITS')

# %% [markdown]
# Let's make sure the new columns correctly account for AMPM...

# %%
mask = df_ampm.STATION == '50 ST'
df_ampm[mask].head(20)
# Out:
#         C/A  UNIT       SCP STATION ZIPCODE ZIPCODE_AGI        DATE AMPM  \
# 58010  E004  R234  00-00-00   50 ST   10019       10019  11/03/2019   AM
# 58011  E004  R234  00-00-00   50 ST   10019       10019  11/03/2019   PM
# 58012  E004  R234  00-00-00   50 ST   10019       10019  11/04/2019   AM
# 58013  E004  R234  00-00-00   50 ST   10019       10019  11/04/2019   PM
# 58014  E004  R234  00-00-00   50 ST   10019       10019  11/05/2019   AM
# 58015  E004  R234  00-00-00   50 ST   10019       10019  11/05/2019   PM
# 58016  E004  R234  00-00-00   50 ST   10019       10019  11/06/2019   AM
# 58017  E004  R234  00-00-00   50 ST   10019       10019  11/06/2019   PM
# 58018  E004  R234  00-00-00   50 ST   10019       10019  11/07/2019   AM
# 58019  E004  R234  00-00-00   50 ST   10019       10019  11/07/2019   PM
# 58020  E004  R234  00-00-00   50 ST   10019       10019  11/08/2019   AM
# 58021  E004  R234  00-00-00   50 ST   10019       10019  11/08/2019   PM
# 58022  E004  R234  00-00-00   50 ST   10019       10019  11/09/2019   AM
# 58023  E004  R234  00-00-00   50 ST   10019       10019  11/09/2019   PM
# 58024  E004  R234  00-00-00   50 ST   10019       10019  11/10/2019   AM
# 58025  E004  R234  00-00-00   50 ST   10019       10019  11/10/2019   PM
# 58026  E004  R234  00-00-00   50 ST   10019       10019  11/11/2019   AM
# 58027  E004  R234  00-00-00   50 ST   10019       10019  11/11/2019   PM
# 58028  E004  R234  00-00-00   50 ST   10019       10019  11/12/2019   AM
# 58029  E004  R234  00-00-00   50 ST   10019       10019  11/12/2019   PM
#
#         DAY_NAME  ENTRIES    EXITS   PREV_DATE  PREV_ENTRIES  PREV_EXITS  \
# 58010     Sunday  5948968  5525777  11/02/2019     5948370.0   5525155.0
# 58011     Sunday  5949485  5526198  11/02/2019     5948731.0   5525519.0
# 58012     Monday  5950050  5526601  11/03/2019     5948968.0   5525777.0
# 58013     Monday  5950898  5527285  11/03/2019     5949485.0   5526198.0
# 58014    Tuesday  5951426  5527687  11/04/2019     5950050.0   5526601.0
# 58015    Tuesday  5952283  5528408  11/04/2019     5950898.0   5527285.0
# 58016  Wednesday  5952806  5528836  11/05/2019     5951426.0   5527687.0
# 58017  Wednesday  5953658  5529517  11/05/2019     5952283.0   5528408.0
# 58018   Thursday  5954189  5529999  11/06/2019     5952806.0   5528836.0
# 58019   Thursday  5954997  5530673  11/06/2019     5953658.0   5529517.0
# 58020     Friday  5955502  5531136  11/07/2019     5954189.0   5529999.0
# 58021     Friday  5956200  5531738  11/07/2019     5954997.0   5530673.0
# 58022   Saturday  5956374  5531891  11/08/2019     5955502.0   5531136.0
# 58023   Saturday  5956686  5532262  11/08/2019     5956200.0   5531738.0
# 58024     Sunday  5956877  5532468  11/09/2019     5956374.0   5531891.0
# 58025     Sunday  5957394  5532918  11/09/2019     5956686.0   5532262.0
# 58026     Monday  5957827  5533341  11/10/2019     5956877.0   5532468.0
# 58027     Monday  5958629  5533937  11/10/2019     5957394.0   5532918.0
# 58028    Tuesday  5959206  5534395  11/11/2019     5957827.0   5533341.0
# 58029    Tuesday  5959917  5535118  11/11/2019     5958629.0   5533937.0
#
#        TMP_ENTRIES  TMP_EXITS
# 58010        598.0      622.0
# 58011        754.0      679.0
# 58012       1082.0      824.0
# 58013       1413.0     1087.0
# 58014       1376.0     1086.0
# 58015       1385.0     1123.0
# 58016       1380.0     1149.0
# 58017       1375.0     1109.0
# 58018       1383.0     1163.0
# 58019       1339.0     1156.0
# 58020       1313.0     1137.0
# 58021       1203.0     1065.0
# 58022        872.0      755.0
# 58023        486.0      524.0
# 58024        503.0      577.0
# 58025        708.0      656.0
# 58026        950.0      873.0
# 58027       1235.0     1019.0
# 58028       1379.0     1054.0
# 58029       1288.0     1181.0

# %% [markdown]
# That's all for the data cleaning! As I mentioned before, all of this code is scripted out in ``clean2.py``'s ``data_wrangling`` function. It returns a tuple of the dataFrames we created above, ``df_turnstiles`` and ``df_ampm``.
#
# Now, you can open ``fresh_start.ipynb`` and try it out for yourself!
